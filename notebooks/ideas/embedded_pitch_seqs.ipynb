# %% [markdown]
# # Pitch sequences embedded in scale changes
#
# ## Deriving pitch class sequences from a series of pitch class sets
#
# When writing a piece of music that contains a sequence of chord or key changes, you often want to write parts that source pitches from said chords/keys.
# For example, if you have a 4 bar loop that goes `C, G, Dm, F`, then you may want to have a bass line that goes `C, G, D, F`, or `E, D, F, F`, or `G, B, A, A`, etc...
#
# One can account for the set of all possible such sequences by taking the cartesian product of the pitch class sets.
#
# In our example, the pitch class set sequence would be
#
# ```
# [
#     {0,4,7} mod 12 root 0,
#     {2,7,11} mod 12 root 7,
#     {2,5,9} mod 12 root 2,
#     {0,5,9} mod 12 root 5
# ]
# ```
#
# From this sequence of pitch class sets, we can pick one pitch class from each set, giving us sequences like `[0,2,2,0]`, `[0,2,2,5]`, etc...

# %%
import itertools
from harmonica.pitch import PitchClassSet


def pcseqs_from_pcset_seq(pcset_seq: list[PitchClassSet]) -> list[list[int]]:
    pcseqs = []

    assert all(
        [pcset.modulus == pcset_seq[0].modulus for pcset in pcset_seq]
    ), "Pitch class sets must all have the same modulus."

    modulus = pcset_seq[0].modulus
    pcsets = [pcset.pitch_classes for pcset in pcset_seq]

    for pcseq in itertools.product(*pcsets):
        pcseqs.append(list(pcseq))

    return pcseqs


pcs = [PitchClassSet(x, 12) for x in [[0, 4, 7], [2, 7, 11], [2, 5, 9], [0, 5, 9]]]

pcseqs = pcseqs_from_pcset_seq(pcs)

for pcseq in pcseqs:
    print(pcseq)
# Out:
# [0, 2, 2, 0]
# [0, 2, 2, 5]
# [0, 2, 2, 9]
# [0, 2, 5, 0]
# [0, 2, 5, 5]
# [0, 2, 5, 9]
# [0, 2, 9, 0]
# [0, 2, 9, 5]
# [0, 2, 9, 9]
# [0, 7, 2, 0]
# [0, 7, 2, 5]
# [0, 7, 2, 9]
# [0, 7, 5, 0]
# [0, 7, 5, 5]
# [0, 7, 5, 9]
# [0, 7, 9, 0]
# [0, 7, 9, 5]
# [0, 7, 9, 9]
# [0, 11, 2, 0]
# [0, 11, 2, 5]
# [0, 11, 2, 9]
# [0, 11, 5, 0]
# [0, 11, 5, 5]
# [0, 11, 5, 9]
# [0, 11, 9, 0]
# [0, 11, 9, 5]
# [0, 11, 9, 9]
# [4, 2, 2, 0]
# [4, 2, 2, 5]
# [4, 2, 2, 9]
# [4, 2, 5, 0]
# [4, 2, 5, 5]
# [4, 2, 5, 9]
# [4, 2, 9, 0]
# [4, 2, 9, 5]
# [4, 2, 9, 9]
# [4, 7, 2, 0]
# [4, 7, 2, 5]
# [4, 7, 2, 9]
# [4, 7, 5, 0]
# [4, 7, 5, 5]
# [4, 7, 5, 9]
# [4, 7, 9, 0]
# [4, 7, 9, 5]
# [4, 7, 9, 9]
# [4, 11, 2, 0]
# [4, 11, 2, 5]
# [4, 11, 2, 9]
# [4, 11, 5, 0]
# [4, 11, 5, 5]
# [4, 11, 5, 9]
# [4, 11, 9, 0]
# [4, 11, 9, 5]
# [4, 11, 9, 9]
# [7, 2, 2, 0]
# [7, 2, 2, 5]
# [7, 2, 2, 9]
# [7, 2, 5, 0]
# [7, 2, 5, 5]
# [7, 2, 5, 9]
# [7, 2, 9, 0]
# [7, 2, 9, 5]
# [7, 2, 9, 9]
# [7, 7, 2, 0]
# [7, 7, 2, 5]
# [7, 7, 2, 9]
# [7, 7, 5, 0]
# [7, 7, 5, 5]
# [7, 7, 5, 9]
# [7, 7, 9, 0]
# [7, 7, 9, 5]
# [7, 7, 9, 9]
# [7, 11, 2, 0]
# [7, 11, 2, 5]
# [7, 11, 2, 9]
# [7, 11, 5, 0]
# [7, 11, 5, 5]
# [7, 11, 5, 9]
# [7, 11, 9, 0]
# [7, 11, 9, 5]
# [7, 11, 9, 9]

# %% [markdown]
# ## Deriving pitch sequences from pitch class sequences
#
# From any given pitch class sequence, we can derive infinitely many pitch sequences, because a pitch class represents every possible octave.
# There aren't infinitely many (audible) pitches, of course, so this isn't very useful. Therefore, we should aim to reduce this infinite set
# of pitch sequences to a finite set.
#
# To do this, we must specify a range of octaves. For example, if we have a pitch class `7`, then all pitches with pitch class `7`
# between octaves 2 and 4 would be given by taking `12 * 2 + 7`, `12 * 3 + 7` and `12 * 4 + 7`, giving us 31, 43 and 55.

# %%
def pcseq_to_pseqs(
    pcseq: list[int], mod: int, min_octave: int, max_octave: int
) -> list[list[int]]:
    pseqs = []

    next_list = [
        [mod * oct + pc for oct in range(min_octave, max_octave + 1)] for pc in pcseq
    ]

    for pseq in itertools.product(*next_list):
        pseqs.append(list(pseq))

    return pseqs


print(pcseq_to_pseqs([7, 2, 4], 12, 3, 5))
# Out:
# [[43, 38, 40], [43, 38, 52], [43, 38, 64], [43, 50, 40], [43, 50, 52], [43, 50, 64], [43, 62, 40], [43, 62, 52], [43, 62, 64], [55, 38, 40], [55, 38, 52], [55, 38, 64], [55, 50, 40], [55, 50, 52], [55, 50, 64], [55, 62, 40], [55, 62, 52], [55, 62, 64], [67, 38, 40], [67, 38, 52], [67, 38, 64], [67, 50, 40], [67, 50, 52], [67, 50, 64], [67, 62, 40], [67, 62, 52], [67, 62, 64]]

# %% [markdown]
# Wow, that is epic. Why don't we just create a clip where we listen through all of these sequences? Hell yeah.
#
# Let's put chords on top too, for harmonic context. The pitch class sequence is `[7,2,4]`, so let's make the chords Em, G, C.
#
# To be more specific about what we're doing here: let's listen to all pitch sequences that can be derived from this chord progression,
# contained to a single octave of pitches.

# %%
from harmonica.pitch import PitchSet
from harmonica.time import Clip, NoteClip, Note
from harmonica.utility._mixed import Mixed

pseqs = []
for pcseq in pcseqs_from_pcset_seq(
    [
        PitchClassSet(pitch_classes, 12)
        for pitch_classes in [[4, 7, 11], [2, 7, 11], [0, 4, 7]]
    ]
):
    pseqs += pcseq_to_pseqs(pcseq, 12, 5, 5)

chords = [
    chord.invert(2)
    for chord in [
        PitchSet([4, 7, 11]) + 60,
        PitchSet([2, 7, 11]) + 60,
        PitchSet([0, 4, 7]) + 60,
    ]
]

bass_clip = NoteClip([]).set_program(34)
chord_clip = NoteClip([]).set_program(5)

onset = Mixed(0)

for pitch_sequence in pseqs:
    for i, pitch in enumerate(pitch_sequence):
        bass_clip.add_event(Note(pitch=pitch, onset=onset, duration=Mixed(1)))
        chord_clip.add_event(chords[i].to_clip(onset=onset, duration=Mixed(1)))
        onset += Mixed(1)
    onset += Mixed(1)

# Uncomment this to preview
# Clip([bass_clip, chord_clip]).preview(tempo=55)

# %% [markdown]
# ### A problem with this approach
#
# This is really neat. Big fan of enumerating things. There's one problem though, which is that we're basically picking a range
# of pitches, like 60 - 71, and enumerating all pitch sequences with pitches in that range. This isn't very intuitive in terms of voice leading.
#
# I mean, just look at our results. The pitch class sequence `[4,11,0]`, for example. When we derive pitch sequences from this and are only
# considering a fixed range of 60 through 71, we get sequences like `[64,71,60]`, but what about `[64,71,72]`? What about `[64,59,60]`?
#
# The reason this kinda sucks is because we're getting an incomplete account of the intervallic "shapes" that can be derived from a given
# pitch class sequence. Intervals are a _very important feature_ of any pitch structure, so if our goal is to capture entire swathes of musical possibilities,
# then we should aim to enumerate all possible intervallic structures from a sequence of pitch classes.
#
# ### The cooler approach
#
# Here's what you do. You take your pitch class sequence, like `[4,11,0]`.
#
# You start with the first pitch class, 4. You pick an octave, or register, or whatever you want to call it - y'know, `12x + 4`.
# 28, 40, 52, whatever. Let's just stick with 4 to keep things simple.
#
# Now, lets consider the movement from 4 to 11. When moving from one pitch class to another, you have two parameters:
#
# 1. Direction
# 2. Magnitude
#
# When moving from 4 to 11, you can move either up or down. Then, you can add some amount of octaves to the movement.
#
# So you can move up to 11, 23, 35... Or, you can move down to -1, -13, -25...
#
# The only exception to this is when a pitch class moves to itself, in which case you have another choice aside from moving up or down,
# which is to not move at all. +/- 0.

# %% [markdown]
# ### The new algorithm
#
# In the previous algorithm, we specified a range of octaves that we sampled all of our pitches from. In this new algorithm, we only specify the octave of
# the first pitch. Think of this algorithm as a lot more "relative" or "polar" than the previous one.
#
# Another parameter will be the maximum magnitude, also specified in terms of octave. With a max magnitude of 0, we will only yield the pitches immediately
# above and below the previous pitch. That is to say, if the first pitch is 12, and the next pitch class is 4, and the max magnitude is 0, then the set of
# pitches we can sample from are either 4 or 16. If the max magnitude were 1, then we could sample from -8, 4, 16, or 28. And so on and so on...
#
# Using this algorithm, we can enumerate every possible bass line, melody, pattern, WHATEVER! I mean, probably. What am I, a doctor?

# %%
def neighboring_pitches(
    prev_pitch: int, next_pc: int, mod: int, max_mag: int
) -> list[int]:
    """Returns a list of all pitches that belong to pitch class `next_pc` that are
    in the neighborhood of `prev_pitch`.

    `max_mag` is the "radius" of this neighborhood around `prev_pitch`.
    """

    assert mod > 0, "Modulus must be positive."
    assert (
        0 <= next_pc < mod
    ), "Next pitch class must be non-negative and less than modulus."
    assert max_mag >= 0, "Maximum magnitude must be non-negative."

    intervals = []
    interval_class = (next_pc - (prev_pitch % mod)) % mod

    max_mag += 1

    for q in range(-max_mag, max_mag):
        interval = mod * q + interval_class
        if interval not in intervals:
            intervals.append(interval)

    pitches: list[int] = [prev_pitch + interval for interval in intervals]

    if interval_class == 0:
        return pitches[1:]
    else:
        return pitches


def pseq_builder(
    start_pitch: int, pcseq: list[int], mod: int, max_mag: int
) -> list[list[int]]:
    """Builds out a list of pitch sequences from a starting pitch and a list of pitch classes."""

    if pcseq == []:
        return [[start_pitch]]

    pseqs: list[list[int]] = []

    for neighbor in neighboring_pitches(start_pitch, pcseq[0], mod, max_mag):
        pseqs += pseq_builder(neighbor, pcseq[1:], mod, max_mag)

    for pseq in pseqs:
        pseq.insert(0, start_pitch)

    return pseqs


def pcsets_to_pseqs_relative(
    pcset_seq: list[PitchClassSet], starting_octave: int, max_mag: int
) -> list[list[int]]:
    """Takes a sequence of pitch class sets (representing a chord progression or sequence of key changes)
    and derives a list of pitch sequences.

    `starting_octave` determines the octave of the first note in each pitch sequence, and the rest is
    built out intervallically.

    `max_mag` determines how many octaves can be jumped between successive pitches in each sequence.
    `"""

    if pcset_seq == []:
        return []

    modulus = pcset_seq[0].modulus

    assert max_mag >= 0, "Maximum magnitude must be non-negative."
    assert all(
        [pcset.modulus == modulus for pcset in pcset_seq]
    ), "Pitch class sets must all have the same modulus."

    pseqs: list[list[int]] = []

    pcseqs = pcseqs_from_pcset_seq(pcset_seq)

    for pcseq in pcseqs:
        starting_pitch = pcseq[0] + (modulus * starting_octave)
        pseqs += pseq_builder(starting_pitch, pcseq[1:], modulus, max_mag)

    return pseqs


pseqs = pcsets_to_pseqs_relative(
    pcset_seq=[
        PitchClassSet(p_classes, 12)
        for p_classes in [[0, 4, 7], [2, 7, 11], [0, 4, 9], [0, 5, 9]]
    ],
    starting_octave=3,
    max_mag=1,
)

for pitch_sequence in pseqs:
    print(pitch_sequence)
# Out:
# [36, 14, 0, -12]
# [36, 14, 0, 0]
# [36, 14, 0, 12]
# [36, 14, 12, 0]
# [36, 14, 12, 12]
# [36, 14, 12, 24]
# [36, 14, 24, 12]
# [36, 14, 24, 24]
# [36, 14, 24, 36]
# [36, 14, 36, 24]
# [36, 14, 36, 36]
# [36, 14, 36, 48]
# [36, 26, 12, 0]
# [36, 26, 12, 12]
# [36, 26, 12, 24]
# [36, 26, 24, 12]
# [36, 26, 24, 24]
# [36, 26, 24, 36]
# [36, 26, 36, 24]
# [36, 26, 36, 36]
# [36, 26, 36, 48]
# [36, 26, 48, 36]
# [36, 26, 48, 48]
# [36, 26, 48, 60]
# [36, 38, 24, 12]
# [36, 38, 24, 24]
# [36, 38, 24, 36]
# [36, 38, 36, 24]
# [36, 38, 36, 36]
# [36, 38, 36, 48]
# [36, 38, 48, 36]
# [36, 38, 48, 48]
# [36, 38, 48, 60]
# [36, 38, 60, 48]
# [36, 38, 60, 60]
# [36, 38, 60, 72]
# [36, 50, 36, 24]
# [36, 50, 36, 36]
# [36, 50, 36, 48]
# [36, 50, 48, 36]
# [36, 50, 48, 48]
# [36, 50, 48, 60]
# [36, 50, 60, 48]
# [36, 50, 60, 60]
# [36, 50, 60, 72]
# [36, 50, 72, 60]
# [36, 50, 72, 72]
# [36, 50, 72, 84]
# [36, 14, 0, -19]
# [36, 14, 0, -7]
# [36, 14, 0, 5]
# [36, 14, 0, 17]
# [36, 14, 12, -7]
# [36, 14, 12, 5]
# [36, 14, 12, 17]
# [36, 14, 12, 29]
# [36, 14, 24, 5]
# [36, 14, 24, 17]
# [36, 14, 24, 29]
# [36, 14, 24, 41]
# [36, 14, 36, 17]
# [36, 14, 36, 29]
# [36, 14, 36, 41]
# [36, 14, 36, 53]
# [36, 26, 12, -7]
# [36, 26, 12, 5]
# [36, 26, 12, 17]
# [36, 26, 12, 29]
# [36, 26, 24, 5]
# [36, 26, 24, 17]
# [36, 26, 24, 29]
# [36, 26, 24, 41]
# [36, 26, 36, 17]
# [36, 26, 36, 29]
# [36, 26, 36, 41]
# [36, 26, 36, 53]
# [36, 26, 48, 29]
# [36, 26, 48, 41]
# [36, 26, 48, 53]
# [36, 26, 48, 65]
# [36, 38, 24, 5]
# [36, 38, 24, 17]
# [36, 38, 24, 29]
# [36, 38, 24, 41]
# [36, 38, 36, 17]
# [36, 38, 36, 29]
# [36, 38, 36, 41]
# [36, 38, 36, 53]
# [36, 38, 48, 29]
# [36, 38, 48, 41]
# [36, 38, 48, 53]
# [36, 38, 48, 65]
# [36, 38, 60, 41]
# [36, 38, 60, 53]
# [36, 38, 60, 65]
# [36, 38, 60, 77]
# [36, 50, 36, 17]
# [36, 50, 36, 29]
# [36, 50, 36, 41]
# [36, 50, 36, 53]
# [36, 50, 48, 29]
# [36, 50, 48, 41]
# [36, 50, 48, 53]
# [36, 50, 48, 65]
# [36, 50, 60, 41]
# [36, 50, 60, 53]
# [36, 50, 60, 65]
# [36, 50, 60, 77]
# [36, 50, 72, 53]
# [36, 50, 72, 65]
# [36, 50, 72, 77]
# [36, 50, 72, 89]
# [36, 14, 0, -15]
# [36, 14, 0, -3]
# [36, 14, 0, 9]
# [36, 14, 0, 21]
# [36, 14, 12, -3]
# [36, 14, 12, 9]
# [36, 14, 12, 21]
# [36, 14, 12, 33]
# [36, 14, 24, 9]
# [36, 14, 24, 21]
# [36, 14, 24, 33]
# [36, 14, 24, 45]
# [36, 14, 36, 21]
# [36, 14, 36, 33]
# [36, 14, 36, 45]
# [36, 14, 36, 57]
# [36, 26, 12, -3]
# [36, 26, 12, 9]
# [36, 26, 12, 21]
# [36, 26, 12, 33]
# [36, 26, 24, 9]
# [36, 26, 24, 21]
# [36, 26, 24, 33]
# [36, 26, 24, 45]
# [36, 26, 36, 21]
# [36, 26, 36, 33]
# [36, 26, 36, 45]
# [36, 26, 36, 57]
# [36, 26, 48, 33]
# [36, 26, 48, 45]
# [36, 26, 48, 57]
# [36, 26, 48, 69]
# [36, 38, 24, 9]
# [36, 38, 24, 21]
# [36, 38, 24, 33]
# [36, 38, 24, 45]
# [36, 38, 36, 21]
# [36, 38, 36, 33]
# [36, 38, 36, 45]
# [36, 38, 36, 57]
# [36, 38, 48, 33]
# [36, 38, 48, 45]
# [36, 38, 48, 57]
# [36, 38, 48, 69]
# [36, 38, 60, 45]
# [36, 38, 60, 57]
# [36, 38, 60, 69]
# [36, 38, 60, 81]
# [36, 50, 36, 21]
# [36, 50, 36, 33]
# [36, 50, 36, 45]
# [36, 50, 36, 57]
# [36, 50, 48, 33]
# [36, 50, 48, 45]
# [36, 50, 48, 57]
# [36, 50, 48, 69]
# [36, 50, 60, 45]
# [36, 50, 60, 57]
# [36, 50, 60, 69]
# [36, 50, 60, 81]
# [36, 50, 72, 57]
# [36, 50, 72, 69]
# [36, 50, 72, 81]
# [36, 50, 72, 93]
# [36, 14, -8, -24]
# [36, 14, -8, -12]
# [36, 14, -8, 0]
# [36, 14, -8, 12]
# [36, 14, 4, -12]
# [36, 14, 4, 0]
# [36, 14, 4, 12]
# [36, 14, 4, 24]
# [36, 14, 16, 0]
# [36, 14, 16, 12]
# [36, 14, 16, 24]
# [36, 14, 16, 36]
# [36, 14, 28, 12]
# [36, 14, 28, 24]
# [36, 14, 28, 36]
# [36, 14, 28, 48]
# [36, 26, 4, -12]
# [36, 26, 4, 0]
# [36, 26, 4, 12]
# [36, 26, 4, 24]
# [36, 26, 16, 0]
# [36, 26, 16, 12]
# [36, 26, 16, 24]
# [36, 26, 16, 36]
# [36, 26, 28, 12]
# [36, 26, 28, 24]
# [36, 26, 28, 36]
# [36, 26, 28, 48]
# [36, 26, 40, 24]
# [36, 26, 40, 36]
# [36, 26, 40, 48]
# [36, 26, 40, 60]
# [36, 38, 16, 0]
# [36, 38, 16, 12]
# [36, 38, 16, 24]
# [36, 38, 16, 36]
# [36, 38, 28, 12]
# [36, 38, 28, 24]
# [36, 38, 28, 36]
# [36, 38, 28, 48]
# [36, 38, 40, 24]
# [36, 38, 40, 36]
# [36, 38, 40, 48]
# [36, 38, 40, 60]
# [36, 38, 52, 36]
# [36, 38, 52, 48]
# [36, 38, 52, 60]
# [36, 38, 52, 72]
# [36, 50, 28, 12]
# [36, 50, 28, 24]
# [36, 50, 28, 36]
# [36, 50, 28, 48]
# [36, 50, 40, 24]
# [36, 50, 40, 36]
# [36, 50, 40, 48]
# [36, 50, 40, 60]
# [36, 50, 52, 36]
# [36, 50, 52, 48]
# [36, 50, 52, 60]
# [36, 50, 52, 72]
# [36, 50, 64, 48]
# [36, 50, 64, 60]
# [36, 50, 64, 72]
# [36, 50, 64, 84]
# [36, 14, -8, -31]
# [36, 14, -8, -19]
# [36, 14, -8, -7]
# [36, 14, -8, 5]
# [36, 14, 4, -19]
# [36, 14, 4, -7]
# [36, 14, 4, 5]
# [36, 14, 4, 17]
# [36, 14, 16, -7]
# [36, 14, 16, 5]
# [36, 14, 16, 17]
# [36, 14, 16, 29]
# [36, 14, 28, 5]
# [36, 14, 28, 17]
# [36, 14, 28, 29]
# [36, 14, 28, 41]
# [36, 26, 4, -19]
# [36, 26, 4, -7]
# [36, 26, 4, 5]
# [36, 26, 4, 17]
# [36, 26, 16, -7]
# [36, 26, 16, 5]
# [36, 26, 16, 17]
# [36, 26, 16, 29]
# [36, 26, 28, 5]
# [36, 26, 28, 17]
# [36, 26, 28, 29]
# [36, 26, 28, 41]
# [36, 26, 40, 17]
# [36, 26, 40, 29]
# [36, 26, 40, 41]
# [36, 26, 40, 53]
# [36, 38, 16, -7]
# [36, 38, 16, 5]
# [36, 38, 16, 17]
# [36, 38, 16, 29]
# [36, 38, 28, 5]
# [36, 38, 28, 17]
# [36, 38, 28, 29]
# [36, 38, 28, 41]
# [36, 38, 40, 17]
# [36, 38, 40, 29]
# [36, 38, 40, 41]
# [36, 38, 40, 53]
# [36, 38, 52, 29]
# [36, 38, 52, 41]
# [36, 38, 52, 53]
# [36, 38, 52, 65]
# [36, 50, 28, 5]
# [36, 50, 28, 17]
# [36, 50, 28, 29]
# [36, 50, 28, 41]
# [36, 50, 40, 17]
# [36, 50, 40, 29]
# [36, 50, 40, 41]
# [36, 50, 40, 53]
# [36, 50, 52, 29]
# [36, 50, 52, 41]
# [36, 50, 52, 53]
# [36, 50, 52, 65]
# [36, 50, 64, 41]
# [36, 50, 64, 53]
# [36, 50, 64, 65]
# [36, 50, 64, 77]
# [36, 14, -8, -27]
# [36, 14, -8, -15]
# [36, 14, -8, -3]
# [36, 14, -8, 9]
# [36, 14, 4, -15]
# [36, 14, 4, -3]
# [36, 14, 4, 9]
# [36, 14, 4, 21]
# [36, 14, 16, -3]
# [36, 14, 16, 9]
# [36, 14, 16, 21]
# [36, 14, 16, 33]
# [36, 14, 28, 9]
# [36, 14, 28, 21]
# [36, 14, 28, 33]
# [36, 14, 28, 45]
# [36, 26, 4, -15]
# [36, 26, 4, -3]
# [36, 26, 4, 9]
# [36, 26, 4, 21]
# [36, 26, 16, -3]
# [36, 26, 16, 9]
# [36, 26, 16, 21]
# [36, 26, 16, 33]
# [36, 26, 28, 9]
# [36, 26, 28, 21]
# [36, 26, 28, 33]
# [36, 26, 28, 45]
# [36, 26, 40, 21]
# [36, 26, 40, 33]
# [36, 26, 40, 45]
# [36, 26, 40, 57]
# [36, 38, 16, -3]
# [36, 38, 16, 9]
# [36, 38, 16, 21]
# [36, 38, 16, 33]
# [36, 38, 28, 9]
# [36, 38, 28, 21]
# [36, 38, 28, 33]
# [36, 38, 28, 45]
# [36, 38, 40, 21]
# [36, 38, 40, 33]
# [36, 38, 40, 45]
# [36, 38, 40, 57]
# [36, 38, 52, 33]
# [36, 38, 52, 45]
# [36, 38, 52, 57]
# [36, 38, 52, 69]
# [36, 50, 28, 9]
# [36, 50, 28, 21]
# [36, 50, 28, 33]
# [36, 50, 28, 45]
# [36, 50, 40, 21]
# [36, 50, 40, 33]
# [36, 50, 40, 45]
# [36, 50, 40, 57]
# [36, 50, 52, 33]
# [36, 50, 52, 45]
# [36, 50, 52, 57]
# [36, 50, 52, 69]
# [36, 50, 64, 45]
# [36, 50, 64, 57]
# [36, 50, 64, 69]
# [36, 50, 64, 81]
# [36, 14, -3, -24]
# [36, 14, -3, -12]
# [36, 14, -3, 0]
# [36, 14, -3, 12]
# [36, 14, 9, -12]
# [36, 14, 9, 0]
# [36, 14, 9, 12]
# [36, 14, 9, 24]
# [36, 14, 21, 0]
# [36, 14, 21, 12]
# [36, 14, 21, 24]
# [36, 14, 21, 36]
# [36, 14, 33, 12]
# [36, 14, 33, 24]
# [36, 14, 33, 36]
# [36, 14, 33, 48]
# [36, 26, 9, -12]
# [36, 26, 9, 0]
# [36, 26, 9, 12]
# [36, 26, 9, 24]
# [36, 26, 21, 0]
# [36, 26, 21, 12]
# [36, 26, 21, 24]
# [36, 26, 21, 36]
# [36, 26, 33, 12]
# [36, 26, 33, 24]
# [36, 26, 33, 36]
# [36, 26, 33, 48]
# [36, 26, 45, 24]
# [36, 26, 45, 36]
# [36, 26, 45, 48]
# [36, 26, 45, 60]
# [36, 38, 21, 0]
# [36, 38, 21, 12]
# [36, 38, 21, 24]
# [36, 38, 21, 36]
# [36, 38, 33, 12]
# [36, 38, 33, 24]
# [36, 38, 33, 36]
# [36, 38, 33, 48]
# [36, 38, 45, 24]
# [36, 38, 45, 36]
# [36, 38, 45, 48]
# [36, 38, 45, 60]
# [36, 38, 57, 36]
# [36, 38, 57, 48]
# [36, 38, 57, 60]
# [36, 38, 57, 72]
# [36, 50, 33, 12]
# [36, 50, 33, 24]
# [36, 50, 33, 36]
# [36, 50, 33, 48]
# [36, 50, 45, 24]
# [36, 50, 45, 36]
# [36, 50, 45, 48]
# [36, 50, 45, 60]
# [36, 50, 57, 36]
# [36, 50, 57, 48]
# [36, 50, 57, 60]
# [36, 50, 57, 72]
# [36, 50, 69, 48]
# [36, 50, 69, 60]
# [36, 50, 69, 72]
# [36, 50, 69, 84]
# [36, 14, -3, -19]
# [36, 14, -3, -7]
# [36, 14, -3, 5]
# [36, 14, -3, 17]
# [36, 14, 9, -7]
# [36, 14, 9, 5]
# [36, 14, 9, 17]
# [36, 14, 9, 29]
# [36, 14, 21, 5]
# [36, 14, 21, 17]
# [36, 14, 21, 29]
# [36, 14, 21, 41]
# [36, 14, 33, 17]
# [36, 14, 33, 29]
# [36, 14, 33, 41]
# [36, 14, 33, 53]
# [36, 26, 9, -7]
# [36, 26, 9, 5]
# [36, 26, 9, 17]
# [36, 26, 9, 29]
# [36, 26, 21, 5]
# [36, 26, 21, 17]
# [36, 26, 21, 29]
# [36, 26, 21, 41]
# [36, 26, 33, 17]
# [36, 26, 33, 29]
# [36, 26, 33, 41]
# [36, 26, 33, 53]
# [36, 26, 45, 29]
# [36, 26, 45, 41]
# [36, 26, 45, 53]
# [36, 26, 45, 65]
# [36, 38, 21, 5]
# [36, 38, 21, 17]
# [36, 38, 21, 29]
# [36, 38, 21, 41]
# [36, 38, 33, 17]
# [36, 38, 33, 29]
# [36, 38, 33, 41]
# [36, 38, 33, 53]
# [36, 38, 45, 29]
# [36, 38, 45, 41]
# [36, 38, 45, 53]
# [36, 38, 45, 65]
# [36, 38, 57, 41]
# [36, 38, 57, 53]
# [36, 38, 57, 65]
# [36, 38, 57, 77]
# [36, 50, 33, 17]
# [36, 50, 33, 29]
# [36, 50, 33, 41]
# [36, 50, 33, 53]
# [36, 50, 45, 29]
# [36, 50, 45, 41]
# [36, 50, 45, 53]
# [36, 50, 45, 65]
# [36, 50, 57, 41]
# [36, 50, 57, 53]
# [36, 50, 57, 65]
# [36, 50, 57, 77]
# [36, 50, 69, 53]
# [36, 50, 69, 65]
# [36, 50, 69, 77]
# [36, 50, 69, 89]
# [36, 14, -3, -15]
# [36, 14, -3, -3]
# [36, 14, -3, 9]
# [36, 14, 9, -3]
# [36, 14, 9, 9]
# [36, 14, 9, 21]
# [36, 14, 21, 9]
# [36, 14, 21, 21]
# [36, 14, 21, 33]
# [36, 14, 33, 21]
# [36, 14, 33, 33]
# [36, 14, 33, 45]
# [36, 26, 9, -3]
# [36, 26, 9, 9]
# [36, 26, 9, 21]
# [36, 26, 21, 9]
# [36, 26, 21, 21]
# [36, 26, 21, 33]
# [36, 26, 33, 21]
# [36, 26, 33, 33]
# [36, 26, 33, 45]
# [36, 26, 45, 33]
# [36, 26, 45, 45]
# [36, 26, 45, 57]
# [36, 38, 21, 9]
# [36, 38, 21, 21]
# [36, 38, 21, 33]
# [36, 38, 33, 21]
# [36, 38, 33, 33]
# [36, 38, 33, 45]
# [36, 38, 45, 33]
# [36, 38, 45, 45]
# [36, 38, 45, 57]
# [36, 38, 57, 45]
# [36, 38, 57, 57]
# [36, 38, 57, 69]
# [36, 50, 33, 21]
# [36, 50, 33, 33]
# [36, 50, 33, 45]
# [36, 50, 45, 33]
# [36, 50, 45, 45]
# [36, 50, 45, 57]
# [36, 50, 57, 45]
# [36, 50, 57, 57]
# [36, 50, 57, 69]
# [36, 50, 69, 57]
# [36, 50, 69, 69]
# [36, 50, 69, 81]
# [36, 19, 0, -12]
# [36, 19, 0, 0]
# [36, 19, 0, 12]
# [36, 19, 12, 0]
# [36, 19, 12, 12]
# [36, 19, 12, 24]
# [36, 19, 24, 12]
# [36, 19, 24, 24]
# [36, 19, 24, 36]
# [36, 19, 36, 24]
# [36, 19, 36, 36]
# [36, 19, 36, 48]
# [36, 31, 12, 0]
# [36, 31, 12, 12]
# [36, 31, 12, 24]
# [36, 31, 24, 12]
# [36, 31, 24, 24]
# [36, 31, 24, 36]
# [36, 31, 36, 24]
# [36, 31, 36, 36]
# [36, 31, 36, 48]
# [36, 31, 48, 36]
# [36, 31, 48, 48]
# [36, 31, 48, 60]
# [36, 43, 24, 12]
# [36, 43, 24, 24]
# [36, 43, 24, 36]
# [36, 43, 36, 24]
# [36, 43, 36, 36]
# [36, 43, 36, 48]
# [36, 43, 48, 36]
# [36, 43, 48, 48]
# [36, 43, 48, 60]
# [36, 43, 60, 48]
# [36, 43, 60, 60]
# [36, 43, 60, 72]
# [36, 55, 36, 24]
# [36, 55, 36, 36]
# [36, 55, 36, 48]
# [36, 55, 48, 36]
# [36, 55, 48, 48]
# [36, 55, 48, 60]
# [36, 55, 60, 48]
# [36, 55, 60, 60]
# [36, 55, 60, 72]
# [36, 55, 72, 60]
# [36, 55, 72, 72]
# [36, 55, 72, 84]
# [36, 19, 0, -19]
# [36, 19, 0, -7]
# [36, 19, 0, 5]
# [36, 19, 0, 17]
# [36, 19, 12, -7]
# [36, 19, 12, 5]
# [36, 19, 12, 17]
# [36, 19, 12, 29]
# [36, 19, 24, 5]
# [36, 19, 24, 17]
# [36, 19, 24, 29]
# [36, 19, 24, 41]
# [36, 19, 36, 17]
# [36, 19, 36, 29]
# [36, 19, 36, 41]
# [36, 19, 36, 53]
# [36, 31, 12, -7]
# [36, 31, 12, 5]
# [36, 31, 12, 17]
# [36, 31, 12, 29]
# [36, 31, 24, 5]
# [36, 31, 24, 17]
# [36, 31, 24, 29]
# [36, 31, 24, 41]
# [36, 31, 36, 17]
# [36, 31, 36, 29]
# [36, 31, 36, 41]
# [36, 31, 36, 53]
# [36, 31, 48, 29]
# [36, 31, 48, 41]
# [36, 31, 48, 53]
# [36, 31, 48, 65]
# [36, 43, 24, 5]
# [36, 43, 24, 17]
# [36, 43, 24, 29]
# [36, 43, 24, 41]
# [36, 43, 36, 17]
# [36, 43, 36, 29]
# [36, 43, 36, 41]
# [36, 43, 36, 53]
# [36, 43, 48, 29]
# [36, 43, 48, 41]
# [36, 43, 48, 53]
# [36, 43, 48, 65]
# [36, 43, 60, 41]
# [36, 43, 60, 53]
# [36, 43, 60, 65]
# [36, 43, 60, 77]
# [36, 55, 36, 17]
# [36, 55, 36, 29]
# [36, 55, 36, 41]
# [36, 55, 36, 53]
# [36, 55, 48, 29]
# [36, 55, 48, 41]
# [36, 55, 48, 53]
# [36, 55, 48, 65]
# [36, 55, 60, 41]
# [36, 55, 60, 53]
# [36, 55, 60, 65]
# [36, 55, 60, 77]
# [36, 55, 72, 53]
# [36, 55, 72, 65]
# [36, 55, 72, 77]
# [36, 55, 72, 89]
# [36, 19, 0, -15]
# [36, 19, 0, -3]
# [36, 19, 0, 9]
# [36, 19, 0, 21]
# [36, 19, 12, -3]
# [36, 19, 12, 9]
# [36, 19, 12, 21]
# [36, 19, 12, 33]
# [36, 19, 24, 9]
# [36, 19, 24, 21]
# [36, 19, 24, 33]
# [36, 19, 24, 45]
# [36, 19, 36, 21]
# [36, 19, 36, 33]
# [36, 19, 36, 45]
# [36, 19, 36, 57]
# [36, 31, 12, -3]
# [36, 31, 12, 9]
# [36, 31, 12, 21]
# [36, 31, 12, 33]
# [36, 31, 24, 9]
# [36, 31, 24, 21]
# [36, 31, 24, 33]
# [36, 31, 24, 45]
# [36, 31, 36, 21]
# [36, 31, 36, 33]
# [36, 31, 36, 45]
# [36, 31, 36, 57]
# [36, 31, 48, 33]
# [36, 31, 48, 45]
# [36, 31, 48, 57]
# [36, 31, 48, 69]
# [36, 43, 24, 9]
# [36, 43, 24, 21]
# [36, 43, 24, 33]
# [36, 43, 24, 45]
# [36, 43, 36, 21]
# [36, 43, 36, 33]
# [36, 43, 36, 45]
# [36, 43, 36, 57]
# [36, 43, 48, 33]
# [36, 43, 48, 45]
# [36, 43, 48, 57]
# [36, 43, 48, 69]
# [36, 43, 60, 45]
# [36, 43, 60, 57]
# [36, 43, 60, 69]
# [36, 43, 60, 81]
# [36, 55, 36, 21]
# [36, 55, 36, 33]
# [36, 55, 36, 45]
# [36, 55, 36, 57]
# [36, 55, 48, 33]
# [36, 55, 48, 45]
# [36, 55, 48, 57]
# [36, 55, 48, 69]
# [36, 55, 60, 45]
# [36, 55, 60, 57]
# [36, 55, 60, 69]
# [36, 55, 60, 81]
# [36, 55, 72, 57]
# [36, 55, 72, 69]
# [36, 55, 72, 81]
# [36, 55, 72, 93]
# [36, 19, 4, -12]
# [36, 19, 4, 0]
# [36, 19, 4, 12]
# [36, 19, 4, 24]
# [36, 19, 16, 0]
# [36, 19, 16, 12]
# [36, 19, 16, 24]
# [36, 19, 16, 36]
# [36, 19, 28, 12]
# [36, 19, 28, 24]
# [36, 19, 28, 36]
# [36, 19, 28, 48]
# [36, 19, 40, 24]
# [36, 19, 40, 36]
# [36, 19, 40, 48]
# [36, 19, 40, 60]
# [36, 31, 16, 0]
# [36, 31, 16, 12]
# [36, 31, 16, 24]
# [36, 31, 16, 36]
# [36, 31, 28, 12]
# [36, 31, 28, 24]
# [36, 31, 28, 36]
# [36, 31, 28, 48]
# [36, 31, 40, 24]
# [36, 31, 40, 36]
# [36, 31, 40, 48]
# [36, 31, 40, 60]
# [36, 31, 52, 36]
# [36, 31, 52, 48]
# [36, 31, 52, 60]
# [36, 31, 52, 72]
# [36, 43, 28, 12]
# [36, 43, 28, 24]
# [36, 43, 28, 36]
# [36, 43, 28, 48]
# [36, 43, 40, 24]
# [36, 43, 40, 36]
# [36, 43, 40, 48]
# [36, 43, 40, 60]
# [36, 43, 52, 36]
# [36, 43, 52, 48]
# [36, 43, 52, 60]
# [36, 43, 52, 72]
# [36, 43, 64, 48]
# [36, 43, 64, 60]
# [36, 43, 64, 72]
# [36, 43, 64, 84]
# [36, 55, 40, 24]
# [36, 55, 40, 36]
# [36, 55, 40, 48]
# [36, 55, 40, 60]
# [36, 55, 52, 36]
# [36, 55, 52, 48]
# [36, 55, 52, 60]
# [36, 55, 52, 72]
# [36, 55, 64, 48]
# [36, 55, 64, 60]
# [36, 55, 64, 72]
# [36, 55, 64, 84]
# [36, 55, 76, 60]
# [36, 55, 76, 72]
# [36, 55, 76, 84]
# [36, 55, 76, 96]
# [36, 19, 4, -19]
# [36, 19, 4, -7]
# [36, 19, 4, 5]
# [36, 19, 4, 17]
# [36, 19, 16, -7]
# [36, 19, 16, 5]
# [36, 19, 16, 17]
# [36, 19, 16, 29]
# [36, 19, 28, 5]
# [36, 19, 28, 17]
# [36, 19, 28, 29]
# [36, 19, 28, 41]
# [36, 19, 40, 17]
# [36, 19, 40, 29]
# [36, 19, 40, 41]
# [36, 19, 40, 53]
# [36, 31, 16, -7]
# [36, 31, 16, 5]
# [36, 31, 16, 17]
# [36, 31, 16, 29]
# [36, 31, 28, 5]
# [36, 31, 28, 17]
# [36, 31, 28, 29]
# [36, 31, 28, 41]
# [36, 31, 40, 17]
# [36, 31, 40, 29]
# [36, 31, 40, 41]
# [36, 31, 40, 53]
# [36, 31, 52, 29]
# [36, 31, 52, 41]
# [36, 31, 52, 53]
# [36, 31, 52, 65]
# [36, 43, 28, 5]
# [36, 43, 28, 17]
# [36, 43, 28, 29]
# [36, 43, 28, 41]
# [36, 43, 40, 17]
# [36, 43, 40, 29]
# [36, 43, 40, 41]
# [36, 43, 40, 53]
# [36, 43, 52, 29]
# [36, 43, 52, 41]
# [36, 43, 52, 53]
# [36, 43, 52, 65]
# [36, 43, 64, 41]
# [36, 43, 64, 53]
# [36, 43, 64, 65]
# [36, 43, 64, 77]
# [36, 55, 40, 17]
# [36, 55, 40, 29]
# [36, 55, 40, 41]
# [36, 55, 40, 53]
# [36, 55, 52, 29]
# [36, 55, 52, 41]
# [36, 55, 52, 53]
# [36, 55, 52, 65]
# [36, 55, 64, 41]
# [36, 55, 64, 53]
# [36, 55, 64, 65]
# [36, 55, 64, 77]
# [36, 55, 76, 53]
# [36, 55, 76, 65]
# [36, 55, 76, 77]
# [36, 55, 76, 89]
# [36, 19, 4, -15]
# [36, 19, 4, -3]
# [36, 19, 4, 9]
# [36, 19, 4, 21]
# [36, 19, 16, -3]
# [36, 19, 16, 9]
# [36, 19, 16, 21]
# [36, 19, 16, 33]
# [36, 19, 28, 9]
# [36, 19, 28, 21]
# [36, 19, 28, 33]
# [36, 19, 28, 45]
# [36, 19, 40, 21]
# [36, 19, 40, 33]
# [36, 19, 40, 45]
# [36, 19, 40, 57]
# [36, 31, 16, -3]
# [36, 31, 16, 9]
# [36, 31, 16, 21]
# [36, 31, 16, 33]
# [36, 31, 28, 9]
# [36, 31, 28, 21]
# [36, 31, 28, 33]
# [36, 31, 28, 45]
# [36, 31, 40, 21]
# [36, 31, 40, 33]
# [36, 31, 40, 45]
# [36, 31, 40, 57]
# [36, 31, 52, 33]
# [36, 31, 52, 45]
# [36, 31, 52, 57]
# [36, 31, 52, 69]
# [36, 43, 28, 9]
# [36, 43, 28, 21]
# [36, 43, 28, 33]
# [36, 43, 28, 45]
# [36, 43, 40, 21]
# [36, 43, 40, 33]
# [36, 43, 40, 45]
# [36, 43, 40, 57]
# [36, 43, 52, 33]
# [36, 43, 52, 45]
# [36, 43, 52, 57]
# [36, 43, 52, 69]
# [36, 43, 64, 45]
# [36, 43, 64, 57]
# [36, 43, 64, 69]
# [36, 43, 64, 81]
# [36, 55, 40, 21]
# [36, 55, 40, 33]
# [36, 55, 40, 45]
# [36, 55, 40, 57]
# [36, 55, 52, 33]
# [36, 55, 52, 45]
# [36, 55, 52, 57]
# [36, 55, 52, 69]
# [36, 55, 64, 45]
# [36, 55, 64, 57]
# [36, 55, 64, 69]
# [36, 55, 64, 81]
# [36, 55, 76, 57]
# [36, 55, 76, 69]
# [36, 55, 76, 81]
# [36, 55, 76, 93]
# [36, 19, -3, -24]
# [36, 19, -3, -12]
# [36, 19, -3, 0]
# [36, 19, -3, 12]
# [36, 19, 9, -12]
# [36, 19, 9, 0]
# [36, 19, 9, 12]
# [36, 19, 9, 24]
# [36, 19, 21, 0]
# [36, 19, 21, 12]
# [36, 19, 21, 24]
# [36, 19, 21, 36]
# [36, 19, 33, 12]
# [36, 19, 33, 24]
# [36, 19, 33, 36]
# [36, 19, 33, 48]
# [36, 31, 9, -12]
# [36, 31, 9, 0]
# [36, 31, 9, 12]
# [36, 31, 9, 24]
# [36, 31, 21, 0]
# [36, 31, 21, 12]
# [36, 31, 21, 24]
# [36, 31, 21, 36]
# [36, 31, 33, 12]
# [36, 31, 33, 24]
# [36, 31, 33, 36]
# [36, 31, 33, 48]
# [36, 31, 45, 24]
# [36, 31, 45, 36]
# [36, 31, 45, 48]
# [36, 31, 45, 60]
# [36, 43, 21, 0]
# [36, 43, 21, 12]
# [36, 43, 21, 24]
# [36, 43, 21, 36]
# [36, 43, 33, 12]
# [36, 43, 33, 24]
# [36, 43, 33, 36]
# [36, 43, 33, 48]
# [36, 43, 45, 24]
# [36, 43, 45, 36]
# [36, 43, 45, 48]
# [36, 43, 45, 60]
# [36, 43, 57, 36]
# [36, 43, 57, 48]
# [36, 43, 57, 60]
# [36, 43, 57, 72]
# [36, 55, 33, 12]
# [36, 55, 33, 24]
# [36, 55, 33, 36]
# [36, 55, 33, 48]
# [36, 55, 45, 24]
# [36, 55, 45, 36]
# [36, 55, 45, 48]
# [36, 55, 45, 60]
# [36, 55, 57, 36]
# [36, 55, 57, 48]
# [36, 55, 57, 60]
# [36, 55, 57, 72]
# [36, 55, 69, 48]
# [36, 55, 69, 60]
# [36, 55, 69, 72]
# [36, 55, 69, 84]
# [36, 19, -3, -19]
# [36, 19, -3, -7]
# [36, 19, -3, 5]
# [36, 19, -3, 17]
# [36, 19, 9, -7]
# [36, 19, 9, 5]
# [36, 19, 9, 17]
# [36, 19, 9, 29]
# [36, 19, 21, 5]
# [36, 19, 21, 17]
# [36, 19, 21, 29]
# [36, 19, 21, 41]
# [36, 19, 33, 17]
# [36, 19, 33, 29]
# [36, 19, 33, 41]
# [36, 19, 33, 53]
# [36, 31, 9, -7]
# [36, 31, 9, 5]
# [36, 31, 9, 17]
# [36, 31, 9, 29]
# [36, 31, 21, 5]
# [36, 31, 21, 17]
# [36, 31, 21, 29]
# [36, 31, 21, 41]
# [36, 31, 33, 17]
# [36, 31, 33, 29]
# [36, 31, 33, 41]
# [36, 31, 33, 53]
# [36, 31, 45, 29]
# [36, 31, 45, 41]
# [36, 31, 45, 53]
# [36, 31, 45, 65]
# [36, 43, 21, 5]
# [36, 43, 21, 17]
# [36, 43, 21, 29]
# [36, 43, 21, 41]
# [36, 43, 33, 17]
# [36, 43, 33, 29]
# [36, 43, 33, 41]
# [36, 43, 33, 53]
# [36, 43, 45, 29]
# [36, 43, 45, 41]
# [36, 43, 45, 53]
# [36, 43, 45, 65]
# [36, 43, 57, 41]
# [36, 43, 57, 53]
# [36, 43, 57, 65]
# [36, 43, 57, 77]
# [36, 55, 33, 17]
# [36, 55, 33, 29]
# [36, 55, 33, 41]
# [36, 55, 33, 53]
# [36, 55, 45, 29]
# [36, 55, 45, 41]
# [36, 55, 45, 53]
# [36, 55, 45, 65]
# [36, 55, 57, 41]
# [36, 55, 57, 53]
# [36, 55, 57, 65]
# [36, 55, 57, 77]
# [36, 55, 69, 53]
# [36, 55, 69, 65]
# [36, 55, 69, 77]
# [36, 55, 69, 89]
# [36, 19, -3, -15]
# [36, 19, -3, -3]
# [36, 19, -3, 9]
# [36, 19, 9, -3]
# [36, 19, 9, 9]
# [36, 19, 9, 21]
# [36, 19, 21, 9]
# [36, 19, 21, 21]
# [36, 19, 21, 33]
# [36, 19, 33, 21]
# [36, 19, 33, 33]
# [36, 19, 33, 45]
# [36, 31, 9, -3]
# [36, 31, 9, 9]
# [36, 31, 9, 21]
# [36, 31, 21, 9]
# [36, 31, 21, 21]
# [36, 31, 21, 33]
# [36, 31, 33, 21]
# [36, 31, 33, 33]
# [36, 31, 33, 45]
# [36, 31, 45, 33]
# [36, 31, 45, 45]
# [36, 31, 45, 57]
# [36, 43, 21, 9]
# [36, 43, 21, 21]
# [36, 43, 21, 33]
# [36, 43, 33, 21]
# [36, 43, 33, 33]
# [36, 43, 33, 45]
# [36, 43, 45, 33]
# [36, 43, 45, 45]
# [36, 43, 45, 57]
# [36, 43, 57, 45]
# [36, 43, 57, 57]
# [36, 43, 57, 69]
# [36, 55, 33, 21]
# [36, 55, 33, 33]
# [36, 55, 33, 45]
# [36, 55, 45, 33]
# [36, 55, 45, 45]
# [36, 55, 45, 57]
# [36, 55, 57, 45]
# [36, 55, 57, 57]
# [36, 55, 57, 69]
# [36, 55, 69, 57]
# [36, 55, 69, 69]
# [36, 55, 69, 81]
# [36, 23, 0, -12]
# [36, 23, 0, 0]
# [36, 23, 0, 12]
# [36, 23, 12, 0]
# [36, 23, 12, 12]
# [36, 23, 12, 24]
# [36, 23, 24, 12]
# [36, 23, 24, 24]
# [36, 23, 24, 36]
# [36, 23, 36, 24]
# [36, 23, 36, 36]
# [36, 23, 36, 48]
# [36, 35, 12, 0]
# [36, 35, 12, 12]
# [36, 35, 12, 24]
# [36, 35, 24, 12]
# [36, 35, 24, 24]
# [36, 35, 24, 36]
# [36, 35, 36, 24]
# [36, 35, 36, 36]
# [36, 35, 36, 48]
# [36, 35, 48, 36]
# [36, 35, 48, 48]
# [36, 35, 48, 60]
# [36, 47, 24, 12]
# [36, 47, 24, 24]
# [36, 47, 24, 36]
# [36, 47, 36, 24]
# [36, 47, 36, 36]
# [36, 47, 36, 48]
# [36, 47, 48, 36]
# [36, 47, 48, 48]
# [36, 47, 48, 60]
# [36, 47, 60, 48]
# [36, 47, 60, 60]
# [36, 47, 60, 72]
# [36, 59, 36, 24]
# [36, 59, 36, 36]
# [36, 59, 36, 48]
# [36, 59, 48, 36]
# [36, 59, 48, 48]
# [36, 59, 48, 60]
# [36, 59, 60, 48]
# [36, 59, 60, 60]
# [36, 59, 60, 72]
# [36, 59, 72, 60]
# [36, 59, 72, 72]
# [36, 59, 72, 84]
# [36, 23, 0, -19]
# [36, 23, 0, -7]
# [36, 23, 0, 5]
# [36, 23, 0, 17]
# [36, 23, 12, -7]
# [36, 23, 12, 5]
# [36, 23, 12, 17]
# [36, 23, 12, 29]
# [36, 23, 24, 5]
# [36, 23, 24, 17]
# [36, 23, 24, 29]
# [36, 23, 24, 41]
# [36, 23, 36, 17]
# [36, 23, 36, 29]
# [36, 23, 36, 41]
# [36, 23, 36, 53]
# [36, 35, 12, -7]
# [36, 35, 12, 5]
# [36, 35, 12, 17]
# [36, 35, 12, 29]
# [36, 35, 24, 5]
# [36, 35, 24, 17]
# [36, 35, 24, 29]
# [36, 35, 24, 41]
# [36, 35, 36, 17]
# [36, 35, 36, 29]
# [36, 35, 36, 41]
# [36, 35, 36, 53]
# [36, 35, 48, 29]
# [36, 35, 48, 41]
# [36, 35, 48, 53]
# [36, 35, 48, 65]
# [36, 47, 24, 5]
# [36, 47, 24, 17]
# [36, 47, 24, 29]
# [36, 47, 24, 41]
# [36, 47, 36, 17]
# [36, 47, 36, 29]
# [36, 47, 36, 41]
# [36, 47, 36, 53]
# [36, 47, 48, 29]
# [36, 47, 48, 41]
# [36, 47, 48, 53]
# [36, 47, 48, 65]
# [36, 47, 60, 41]
# [36, 47, 60, 53]
# [36, 47, 60, 65]
# [36, 47, 60, 77]
# [36, 59, 36, 17]
# [36, 59, 36, 29]
# [36, 59, 36, 41]
# [36, 59, 36, 53]
# [36, 59, 48, 29]
# [36, 59, 48, 41]
# [36, 59, 48, 53]
# [36, 59, 48, 65]
# [36, 59, 60, 41]
# [36, 59, 60, 53]
# [36, 59, 60, 65]
# [36, 59, 60, 77]
# [36, 59, 72, 53]
# [36, 59, 72, 65]
# [36, 59, 72, 77]
# [36, 59, 72, 89]
# [36, 23, 0, -15]
# [36, 23, 0, -3]
# [36, 23, 0, 9]
# [36, 23, 0, 21]
# [36, 23, 12, -3]
# [36, 23, 12, 9]
# [36, 23, 12, 21]
# [36, 23, 12, 33]
# [36, 23, 24, 9]
# [36, 23, 24, 21]
# [36, 23, 24, 33]
# [36, 23, 24, 45]
# [36, 23, 36, 21]
# [36, 23, 36, 33]
# [36, 23, 36, 45]
# [36, 23, 36, 57]
# [36, 35, 12, -3]
# [36, 35, 12, 9]
# [36, 35, 12, 21]
# [36, 35, 12, 33]
# [36, 35, 24, 9]
# [36, 35, 24, 21]
# [36, 35, 24, 33]
# [36, 35, 24, 45]
# [36, 35, 36, 21]
# [36, 35, 36, 33]
# [36, 35, 36, 45]
# [36, 35, 36, 57]
# [36, 35, 48, 33]
# [36, 35, 48, 45]
# [36, 35, 48, 57]
# [36, 35, 48, 69]
# [36, 47, 24, 9]
# [36, 47, 24, 21]
# [36, 47, 24, 33]
# [36, 47, 24, 45]
# [36, 47, 36, 21]
# [36, 47, 36, 33]
# [36, 47, 36, 45]
# [36, 47, 36, 57]
# [36, 47, 48, 33]
# [36, 47, 48, 45]
# [36, 47, 48, 57]
# [36, 47, 48, 69]
# [36, 47, 60, 45]
# [36, 47, 60, 57]
# [36, 47, 60, 69]
# [36, 47, 60, 81]
# [36, 59, 36, 21]
# [36, 59, 36, 33]
# [36, 59, 36, 45]
# [36, 59, 36, 57]
# [36, 59, 48, 33]
# [36, 59, 48, 45]
# [36, 59, 48, 57]
# [36, 59, 48, 69]
# [36, 59, 60, 45]
# [36, 59, 60, 57]
# [36, 59, 60, 69]
# [36, 59, 60, 81]
# [36, 59, 72, 57]
# [36, 59, 72, 69]
# [36, 59, 72, 81]
# [36, 59, 72, 93]
# [36, 23, 4, -12]
# [36, 23, 4, 0]
# [36, 23, 4, 12]
# [36, 23, 4, 24]
# [36, 23, 16, 0]
# [36, 23, 16, 12]
# [36, 23, 16, 24]
# [36, 23, 16, 36]
# [36, 23, 28, 12]
# [36, 23, 28, 24]
# [36, 23, 28, 36]
# [36, 23, 28, 48]
# [36, 23, 40, 24]
# [36, 23, 40, 36]
# [36, 23, 40, 48]
# [36, 23, 40, 60]
# [36, 35, 16, 0]
# [36, 35, 16, 12]
# [36, 35, 16, 24]
# [36, 35, 16, 36]
# [36, 35, 28, 12]
# [36, 35, 28, 24]
# [36, 35, 28, 36]
# [36, 35, 28, 48]
# [36, 35, 40, 24]
# [36, 35, 40, 36]
# [36, 35, 40, 48]
# [36, 35, 40, 60]
# [36, 35, 52, 36]
# [36, 35, 52, 48]
# [36, 35, 52, 60]
# [36, 35, 52, 72]
# [36, 47, 28, 12]
# [36, 47, 28, 24]
# [36, 47, 28, 36]
# [36, 47, 28, 48]
# [36, 47, 40, 24]
# [36, 47, 40, 36]
# [36, 47, 40, 48]
# [36, 47, 40, 60]
# [36, 47, 52, 36]
# [36, 47, 52, 48]
# [36, 47, 52, 60]
# [36, 47, 52, 72]
# [36, 47, 64, 48]
# [36, 47, 64, 60]
# [36, 47, 64, 72]
# [36, 47, 64, 84]
# [36, 59, 40, 24]
# [36, 59, 40, 36]
# [36, 59, 40, 48]
# [36, 59, 40, 60]
# [36, 59, 52, 36]
# [36, 59, 52, 48]
# [36, 59, 52, 60]
# [36, 59, 52, 72]
# [36, 59, 64, 48]
# [36, 59, 64, 60]
# [36, 59, 64, 72]
# [36, 59, 64, 84]
# [36, 59, 76, 60]
# [36, 59, 76, 72]
# [36, 59, 76, 84]
# [36, 59, 76, 96]
# [36, 23, 4, -19]
# [36, 23, 4, -7]
# [36, 23, 4, 5]
# [36, 23, 4, 17]
# [36, 23, 16, -7]
# [36, 23, 16, 5]
# [36, 23, 16, 17]
# [36, 23, 16, 29]
# [36, 23, 28, 5]
# [36, 23, 28, 17]
# [36, 23, 28, 29]
# [36, 23, 28, 41]
# [36, 23, 40, 17]
# [36, 23, 40, 29]
# [36, 23, 40, 41]
# [36, 23, 40, 53]
# [36, 35, 16, -7]
# [36, 35, 16, 5]
# [36, 35, 16, 17]
# [36, 35, 16, 29]
# [36, 35, 28, 5]
# [36, 35, 28, 17]
# [36, 35, 28, 29]
# [36, 35, 28, 41]
# [36, 35, 40, 17]
# [36, 35, 40, 29]
# [36, 35, 40, 41]
# [36, 35, 40, 53]
# [36, 35, 52, 29]
# [36, 35, 52, 41]
# [36, 35, 52, 53]
# [36, 35, 52, 65]
# [36, 47, 28, 5]
# [36, 47, 28, 17]
# [36, 47, 28, 29]
# [36, 47, 28, 41]
# [36, 47, 40, 17]
# [36, 47, 40, 29]
# [36, 47, 40, 41]
# [36, 47, 40, 53]
# [36, 47, 52, 29]
# [36, 47, 52, 41]
# [36, 47, 52, 53]
# [36, 47, 52, 65]
# [36, 47, 64, 41]
# [36, 47, 64, 53]
# [36, 47, 64, 65]
# [36, 47, 64, 77]
# [36, 59, 40, 17]
# [36, 59, 40, 29]
# [36, 59, 40, 41]
# [36, 59, 40, 53]
# [36, 59, 52, 29]
# [36, 59, 52, 41]
# [36, 59, 52, 53]
# [36, 59, 52, 65]
# [36, 59, 64, 41]
# [36, 59, 64, 53]
# [36, 59, 64, 65]
# [36, 59, 64, 77]
# [36, 59, 76, 53]
# [36, 59, 76, 65]
# [36, 59, 76, 77]
# [36, 59, 76, 89]
# [36, 23, 4, -15]
# [36, 23, 4, -3]
# [36, 23, 4, 9]
# [36, 23, 4, 21]
# [36, 23, 16, -3]
# [36, 23, 16, 9]
# [36, 23, 16, 21]
# [36, 23, 16, 33]
# [36, 23, 28, 9]
# [36, 23, 28, 21]
# [36, 23, 28, 33]
# [36, 23, 28, 45]
# [36, 23, 40, 21]
# [36, 23, 40, 33]
# [36, 23, 40, 45]
# [36, 23, 40, 57]
# [36, 35, 16, -3]
# [36, 35, 16, 9]
# [36, 35, 16, 21]
# [36, 35, 16, 33]
# [36, 35, 28, 9]
# [36, 35, 28, 21]
# [36, 35, 28, 33]
# [36, 35, 28, 45]
# [36, 35, 40, 21]
# [36, 35, 40, 33]
# [36, 35, 40, 45]
# [36, 35, 40, 57]
# [36, 35, 52, 33]
# [36, 35, 52, 45]
# [36, 35, 52, 57]
# [36, 35, 52, 69]
# [36, 47, 28, 9]
# [36, 47, 28, 21]
# [36, 47, 28, 33]
# [36, 47, 28, 45]
# [36, 47, 40, 21]
# [36, 47, 40, 33]
# [36, 47, 40, 45]
# [36, 47, 40, 57]
# [36, 47, 52, 33]
# [36, 47, 52, 45]
# [36, 47, 52, 57]
# [36, 47, 52, 69]
# [36, 47, 64, 45]
# [36, 47, 64, 57]
# [36, 47, 64, 69]
# [36, 47, 64, 81]
# [36, 59, 40, 21]
# [36, 59, 40, 33]
# [36, 59, 40, 45]
# [36, 59, 40, 57]
# [36, 59, 52, 33]
# [36, 59, 52, 45]
# [36, 59, 52, 57]
# [36, 59, 52, 69]
# [36, 59, 64, 45]
# [36, 59, 64, 57]
# [36, 59, 64, 69]
# [36, 59, 64, 81]
# [36, 59, 76, 57]
# [36, 59, 76, 69]
# [36, 59, 76, 81]
# [36, 59, 76, 93]
# [36, 23, 9, -12]
# [36, 23, 9, 0]
# [36, 23, 9, 12]
# [36, 23, 9, 24]
# [36, 23, 21, 0]
# [36, 23, 21, 12]
# [36, 23, 21, 24]
# [36, 23, 21, 36]
# [36, 23, 33, 12]
# [36, 23, 33, 24]
# [36, 23, 33, 36]
# [36, 23, 33, 48]
# [36, 23, 45, 24]
# [36, 23, 45, 36]
# [36, 23, 45, 48]
# [36, 23, 45, 60]
# [36, 35, 21, 0]
# [36, 35, 21, 12]
# [36, 35, 21, 24]
# [36, 35, 21, 36]
# [36, 35, 33, 12]
# [36, 35, 33, 24]
# [36, 35, 33, 36]
# [36, 35, 33, 48]
# [36, 35, 45, 24]
# [36, 35, 45, 36]
# [36, 35, 45, 48]
# [36, 35, 45, 60]
# [36, 35, 57, 36]
# [36, 35, 57, 48]
# [36, 35, 57, 60]
# [36, 35, 57, 72]
# [36, 47, 33, 12]
# [36, 47, 33, 24]
# [36, 47, 33, 36]
# [36, 47, 33, 48]
# [36, 47, 45, 24]
# [36, 47, 45, 36]
# [36, 47, 45, 48]
# [36, 47, 45, 60]
# [36, 47, 57, 36]
# [36, 47, 57, 48]
# [36, 47, 57, 60]
# [36, 47, 57, 72]
# [36, 47, 69, 48]
# [36, 47, 69, 60]
# [36, 47, 69, 72]
# [36, 47, 69, 84]
# [36, 59, 45, 24]
# [36, 59, 45, 36]
# [36, 59, 45, 48]
# [36, 59, 45, 60]
# [36, 59, 57, 36]
# [36, 59, 57, 48]
# [36, 59, 57, 60]
# [36, 59, 57, 72]
# [36, 59, 69, 48]
# [36, 59, 69, 60]
# [36, 59, 69, 72]
# [36, 59, 69, 84]
# [36, 59, 81, 60]
# [36, 59, 81, 72]
# [36, 59, 81, 84]
# [36, 59, 81, 96]
# [36, 23, 9, -7]
# [36, 23, 9, 5]
# [36, 23, 9, 17]
# [36, 23, 9, 29]
# [36, 23, 21, 5]
# [36, 23, 21, 17]
# [36, 23, 21, 29]
# [36, 23, 21, 41]
# [36, 23, 33, 17]
# [36, 23, 33, 29]
# [36, 23, 33, 41]
# [36, 23, 33, 53]
# [36, 23, 45, 29]
# [36, 23, 45, 41]
# [36, 23, 45, 53]
# [36, 23, 45, 65]
# [36, 35, 21, 5]
# [36, 35, 21, 17]
# [36, 35, 21, 29]
# [36, 35, 21, 41]
# [36, 35, 33, 17]
# [36, 35, 33, 29]
# [36, 35, 33, 41]
# [36, 35, 33, 53]
# [36, 35, 45, 29]
# [36, 35, 45, 41]
# [36, 35, 45, 53]
# [36, 35, 45, 65]
# [36, 35, 57, 41]
# [36, 35, 57, 53]
# [36, 35, 57, 65]
# [36, 35, 57, 77]
# [36, 47, 33, 17]
# [36, 47, 33, 29]
# [36, 47, 33, 41]
# [36, 47, 33, 53]
# [36, 47, 45, 29]
# [36, 47, 45, 41]
# [36, 47, 45, 53]
# [36, 47, 45, 65]
# [36, 47, 57, 41]
# [36, 47, 57, 53]
# [36, 47, 57, 65]
# [36, 47, 57, 77]
# [36, 47, 69, 53]
# [36, 47, 69, 65]
# [36, 47, 69, 77]
# [36, 47, 69, 89]
# [36, 59, 45, 29]
# [36, 59, 45, 41]
# [36, 59, 45, 53]
# [36, 59, 45, 65]
# [36, 59, 57, 41]
# [36, 59, 57, 53]
# [36, 59, 57, 65]
# [36, 59, 57, 77]
# [36, 59, 69, 53]
# [36, 59, 69, 65]
# [36, 59, 69, 77]
# [36, 59, 69, 89]
# [36, 59, 81, 65]
# [36, 59, 81, 77]
# [36, 59, 81, 89]
# [36, 59, 81, 101]
# [36, 23, 9, -3]
# [36, 23, 9, 9]
# [36, 23, 9, 21]
# [36, 23, 21, 9]
# [36, 23, 21, 21]
# [36, 23, 21, 33]
# [36, 23, 33, 21]
# [36, 23, 33, 33]
# [36, 23, 33, 45]
# [36, 23, 45, 33]
# [36, 23, 45, 45]
# [36, 23, 45, 57]
# [36, 35, 21, 9]
# [36, 35, 21, 21]
# [36, 35, 21, 33]
# [36, 35, 33, 21]
# [36, 35, 33, 33]
# [36, 35, 33, 45]
# [36, 35, 45, 33]
# [36, 35, 45, 45]
# [36, 35, 45, 57]
# [36, 35, 57, 45]
# [36, 35, 57, 57]
# [36, 35, 57, 69]
# [36, 47, 33, 21]
# [36, 47, 33, 33]
# [36, 47, 33, 45]
# [36, 47, 45, 33]
# [36, 47, 45, 45]
# [36, 47, 45, 57]
# [36, 47, 57, 45]
# [36, 47, 57, 57]
# [36, 47, 57, 69]
# [36, 47, 69, 57]
# [36, 47, 69, 69]
# [36, 47, 69, 81]
# [36, 59, 45, 33]
# [36, 59, 45, 45]
# [36, 59, 45, 57]
# [36, 59, 57, 45]
# [36, 59, 57, 57]
# [36, 59, 57, 69]
# [36, 59, 69, 57]
# [36, 59, 69, 69]
# [36, 59, 69, 81]
# [36, 59, 81, 69]
# [36, 59, 81, 81]
# [36, 59, 81, 93]
# [40, 26, 12, 0]
# [40, 26, 12, 12]
# [40, 26, 12, 24]
# [40, 26, 24, 12]
# [40, 26, 24, 24]
# [40, 26, 24, 36]
# [40, 26, 36, 24]
# [40, 26, 36, 36]
# [40, 26, 36, 48]
# [40, 26, 48, 36]
# [40, 26, 48, 48]
# [40, 26, 48, 60]
# [40, 38, 24, 12]
# [40, 38, 24, 24]
# [40, 38, 24, 36]
# [40, 38, 36, 24]
# [40, 38, 36, 36]
# [40, 38, 36, 48]
# [40, 38, 48, 36]
# [40, 38, 48, 48]
# [40, 38, 48, 60]
# [40, 38, 60, 48]
# [40, 38, 60, 60]
# [40, 38, 60, 72]
# [40, 50, 36, 24]
# [40, 50, 36, 36]
# [40, 50, 36, 48]
# [40, 50, 48, 36]
# [40, 50, 48, 48]
# [40, 50, 48, 60]
# [40, 50, 60, 48]
# [40, 50, 60, 60]
# [40, 50, 60, 72]
# [40, 50, 72, 60]
# [40, 50, 72, 72]
# [40, 50, 72, 84]
# [40, 62, 48, 36]
# [40, 62, 48, 48]
# [40, 62, 48, 60]
# [40, 62, 60, 48]
# [40, 62, 60, 60]
# [40, 62, 60, 72]
# [40, 62, 72, 60]
# [40, 62, 72, 72]
# [40, 62, 72, 84]
# [40, 62, 84, 72]
# [40, 62, 84, 84]
# [40, 62, 84, 96]
# [40, 26, 12, -7]
# [40, 26, 12, 5]
# [40, 26, 12, 17]
# [40, 26, 12, 29]
# [40, 26, 24, 5]
# [40, 26, 24, 17]
# [40, 26, 24, 29]
# [40, 26, 24, 41]
# [40, 26, 36, 17]
# [40, 26, 36, 29]
# [40, 26, 36, 41]
# [40, 26, 36, 53]
# [40, 26, 48, 29]
# [40, 26, 48, 41]
# [40, 26, 48, 53]
# [40, 26, 48, 65]
# [40, 38, 24, 5]
# [40, 38, 24, 17]
# [40, 38, 24, 29]
# [40, 38, 24, 41]
# [40, 38, 36, 17]
# [40, 38, 36, 29]
# [40, 38, 36, 41]
# [40, 38, 36, 53]
# [40, 38, 48, 29]
# [40, 38, 48, 41]
# [40, 38, 48, 53]
# [40, 38, 48, 65]
# [40, 38, 60, 41]
# [40, 38, 60, 53]
# [40, 38, 60, 65]
# [40, 38, 60, 77]
# [40, 50, 36, 17]
# [40, 50, 36, 29]
# [40, 50, 36, 41]
# [40, 50, 36, 53]
# [40, 50, 48, 29]
# [40, 50, 48, 41]
# [40, 50, 48, 53]
# [40, 50, 48, 65]
# [40, 50, 60, 41]
# [40, 50, 60, 53]
# [40, 50, 60, 65]
# [40, 50, 60, 77]
# [40, 50, 72, 53]
# [40, 50, 72, 65]
# [40, 50, 72, 77]
# [40, 50, 72, 89]
# [40, 62, 48, 29]
# [40, 62, 48, 41]
# [40, 62, 48, 53]
# [40, 62, 48, 65]
# [40, 62, 60, 41]
# [40, 62, 60, 53]
# [40, 62, 60, 65]
# [40, 62, 60, 77]
# [40, 62, 72, 53]
# [40, 62, 72, 65]
# [40, 62, 72, 77]
# [40, 62, 72, 89]
# [40, 62, 84, 65]
# [40, 62, 84, 77]
# [40, 62, 84, 89]
# [40, 62, 84, 101]
# [40, 26, 12, -3]
# [40, 26, 12, 9]
# [40, 26, 12, 21]
# [40, 26, 12, 33]
# [40, 26, 24, 9]
# [40, 26, 24, 21]
# [40, 26, 24, 33]
# [40, 26, 24, 45]
# [40, 26, 36, 21]
# [40, 26, 36, 33]
# [40, 26, 36, 45]
# [40, 26, 36, 57]
# [40, 26, 48, 33]
# [40, 26, 48, 45]
# [40, 26, 48, 57]
# [40, 26, 48, 69]
# [40, 38, 24, 9]
# [40, 38, 24, 21]
# [40, 38, 24, 33]
# [40, 38, 24, 45]
# [40, 38, 36, 21]
# [40, 38, 36, 33]
# [40, 38, 36, 45]
# [40, 38, 36, 57]
# [40, 38, 48, 33]
# [40, 38, 48, 45]
# [40, 38, 48, 57]
# [40, 38, 48, 69]
# [40, 38, 60, 45]
# [40, 38, 60, 57]
# [40, 38, 60, 69]
# [40, 38, 60, 81]
# [40, 50, 36, 21]
# [40, 50, 36, 33]
# [40, 50, 36, 45]
# [40, 50, 36, 57]
# [40, 50, 48, 33]
# [40, 50, 48, 45]
# [40, 50, 48, 57]
# [40, 50, 48, 69]
# [40, 50, 60, 45]
# [40, 50, 60, 57]
# [40, 50, 60, 69]
# [40, 50, 60, 81]
# [40, 50, 72, 57]
# [40, 50, 72, 69]
# [40, 50, 72, 81]
# [40, 50, 72, 93]
# [40, 62, 48, 33]
# [40, 62, 48, 45]
# [40, 62, 48, 57]
# [40, 62, 48, 69]
# [40, 62, 60, 45]
# [40, 62, 60, 57]
# [40, 62, 60, 69]
# [40, 62, 60, 81]
# [40, 62, 72, 57]
# [40, 62, 72, 69]
# [40, 62, 72, 81]
# [40, 62, 72, 93]
# [40, 62, 84, 69]
# [40, 62, 84, 81]
# [40, 62, 84, 93]
# [40, 62, 84, 105]
# [40, 26, 4, -12]
# [40, 26, 4, 0]
# [40, 26, 4, 12]
# [40, 26, 4, 24]
# [40, 26, 16, 0]
# [40, 26, 16, 12]
# [40, 26, 16, 24]
# [40, 26, 16, 36]
# [40, 26, 28, 12]
# [40, 26, 28, 24]
# [40, 26, 28, 36]
# [40, 26, 28, 48]
# [40, 26, 40, 24]
# [40, 26, 40, 36]
# [40, 26, 40, 48]
# [40, 26, 40, 60]
# [40, 38, 16, 0]
# [40, 38, 16, 12]
# [40, 38, 16, 24]
# [40, 38, 16, 36]
# [40, 38, 28, 12]
# [40, 38, 28, 24]
# [40, 38, 28, 36]
# [40, 38, 28, 48]
# [40, 38, 40, 24]
# [40, 38, 40, 36]
# [40, 38, 40, 48]
# [40, 38, 40, 60]
# [40, 38, 52, 36]
# [40, 38, 52, 48]
# [40, 38, 52, 60]
# [40, 38, 52, 72]
# [40, 50, 28, 12]
# [40, 50, 28, 24]
# [40, 50, 28, 36]
# [40, 50, 28, 48]
# [40, 50, 40, 24]
# [40, 50, 40, 36]
# [40, 50, 40, 48]
# [40, 50, 40, 60]
# [40, 50, 52, 36]
# [40, 50, 52, 48]
# [40, 50, 52, 60]
# [40, 50, 52, 72]
# [40, 50, 64, 48]
# [40, 50, 64, 60]
# [40, 50, 64, 72]
# [40, 50, 64, 84]
# [40, 62, 40, 24]
# [40, 62, 40, 36]
# [40, 62, 40, 48]
# [40, 62, 40, 60]
# [40, 62, 52, 36]
# [40, 62, 52, 48]
# [40, 62, 52, 60]
# [40, 62, 52, 72]
# [40, 62, 64, 48]
# [40, 62, 64, 60]
# [40, 62, 64, 72]
# [40, 62, 64, 84]
# [40, 62, 76, 60]
# [40, 62, 76, 72]
# [40, 62, 76, 84]
# [40, 62, 76, 96]
# [40, 26, 4, -19]
# [40, 26, 4, -7]
# [40, 26, 4, 5]
# [40, 26, 4, 17]
# [40, 26, 16, -7]
# [40, 26, 16, 5]
# [40, 26, 16, 17]
# [40, 26, 16, 29]
# [40, 26, 28, 5]
# [40, 26, 28, 17]
# [40, 26, 28, 29]
# [40, 26, 28, 41]
# [40, 26, 40, 17]
# [40, 26, 40, 29]
# [40, 26, 40, 41]
# [40, 26, 40, 53]
# [40, 38, 16, -7]
# [40, 38, 16, 5]
# [40, 38, 16, 17]
# [40, 38, 16, 29]
# [40, 38, 28, 5]
# [40, 38, 28, 17]
# [40, 38, 28, 29]
# [40, 38, 28, 41]
# [40, 38, 40, 17]
# [40, 38, 40, 29]
# [40, 38, 40, 41]
# [40, 38, 40, 53]
# [40, 38, 52, 29]
# [40, 38, 52, 41]
# [40, 38, 52, 53]
# [40, 38, 52, 65]
# [40, 50, 28, 5]
# [40, 50, 28, 17]
# [40, 50, 28, 29]
# [40, 50, 28, 41]
# [40, 50, 40, 17]
# [40, 50, 40, 29]
# [40, 50, 40, 41]
# [40, 50, 40, 53]
# [40, 50, 52, 29]
# [40, 50, 52, 41]
# [40, 50, 52, 53]
# [40, 50, 52, 65]
# [40, 50, 64, 41]
# [40, 50, 64, 53]
# [40, 50, 64, 65]
# [40, 50, 64, 77]
# [40, 62, 40, 17]
# [40, 62, 40, 29]
# [40, 62, 40, 41]
# [40, 62, 40, 53]
# [40, 62, 52, 29]
# [40, 62, 52, 41]
# [40, 62, 52, 53]
# [40, 62, 52, 65]
# [40, 62, 64, 41]
# [40, 62, 64, 53]
# [40, 62, 64, 65]
# [40, 62, 64, 77]
# [40, 62, 76, 53]
# [40, 62, 76, 65]
# [40, 62, 76, 77]
# [40, 62, 76, 89]
# [40, 26, 4, -15]
# [40, 26, 4, -3]
# [40, 26, 4, 9]
# [40, 26, 4, 21]
# [40, 26, 16, -3]
# [40, 26, 16, 9]
# [40, 26, 16, 21]
# [40, 26, 16, 33]
# [40, 26, 28, 9]
# [40, 26, 28, 21]
# [40, 26, 28, 33]
# [40, 26, 28, 45]
# [40, 26, 40, 21]
# [40, 26, 40, 33]
# [40, 26, 40, 45]
# [40, 26, 40, 57]
# [40, 38, 16, -3]
# [40, 38, 16, 9]
# [40, 38, 16, 21]
# [40, 38, 16, 33]
# [40, 38, 28, 9]
# [40, 38, 28, 21]
# [40, 38, 28, 33]
# [40, 38, 28, 45]
# [40, 38, 40, 21]
# [40, 38, 40, 33]
# [40, 38, 40, 45]
# [40, 38, 40, 57]
# [40, 38, 52, 33]
# [40, 38, 52, 45]
# [40, 38, 52, 57]
# [40, 38, 52, 69]
# [40, 50, 28, 9]
# [40, 50, 28, 21]
# [40, 50, 28, 33]
# [40, 50, 28, 45]
# [40, 50, 40, 21]
# [40, 50, 40, 33]
# [40, 50, 40, 45]
# [40, 50, 40, 57]
# [40, 50, 52, 33]
# [40, 50, 52, 45]
# [40, 50, 52, 57]
# [40, 50, 52, 69]
# [40, 50, 64, 45]
# [40, 50, 64, 57]
# [40, 50, 64, 69]
# [40, 50, 64, 81]
# [40, 62, 40, 21]
# [40, 62, 40, 33]
# [40, 62, 40, 45]
# [40, 62, 40, 57]
# [40, 62, 52, 33]
# [40, 62, 52, 45]
# [40, 62, 52, 57]
# [40, 62, 52, 69]
# [40, 62, 64, 45]
# [40, 62, 64, 57]
# [40, 62, 64, 69]
# [40, 62, 64, 81]
# [40, 62, 76, 57]
# [40, 62, 76, 69]
# [40, 62, 76, 81]
# [40, 62, 76, 93]
# [40, 26, 9, -12]
# [40, 26, 9, 0]
# [40, 26, 9, 12]
# [40, 26, 9, 24]
# [40, 26, 21, 0]
# [40, 26, 21, 12]
# [40, 26, 21, 24]
# [40, 26, 21, 36]
# [40, 26, 33, 12]
# [40, 26, 33, 24]
# [40, 26, 33, 36]
# [40, 26, 33, 48]
# [40, 26, 45, 24]
# [40, 26, 45, 36]
# [40, 26, 45, 48]
# [40, 26, 45, 60]
# [40, 38, 21, 0]
# [40, 38, 21, 12]
# [40, 38, 21, 24]
# [40, 38, 21, 36]
# [40, 38, 33, 12]
# [40, 38, 33, 24]
# [40, 38, 33, 36]
# [40, 38, 33, 48]
# [40, 38, 45, 24]
# [40, 38, 45, 36]
# [40, 38, 45, 48]
# [40, 38, 45, 60]
# [40, 38, 57, 36]
# [40, 38, 57, 48]
# [40, 38, 57, 60]
# [40, 38, 57, 72]
# [40, 50, 33, 12]
# [40, 50, 33, 24]
# [40, 50, 33, 36]
# [40, 50, 33, 48]
# [40, 50, 45, 24]
# [40, 50, 45, 36]
# [40, 50, 45, 48]
# [40, 50, 45, 60]
# [40, 50, 57, 36]
# [40, 50, 57, 48]
# [40, 50, 57, 60]
# [40, 50, 57, 72]
# [40, 50, 69, 48]
# [40, 50, 69, 60]
# [40, 50, 69, 72]
# [40, 50, 69, 84]
# [40, 62, 45, 24]
# [40, 62, 45, 36]
# [40, 62, 45, 48]
# [40, 62, 45, 60]
# [40, 62, 57, 36]
# [40, 62, 57, 48]
# [40, 62, 57, 60]
# [40, 62, 57, 72]
# [40, 62, 69, 48]
# [40, 62, 69, 60]
# [40, 62, 69, 72]
# [40, 62, 69, 84]
# [40, 62, 81, 60]
# [40, 62, 81, 72]
# [40, 62, 81, 84]
# [40, 62, 81, 96]
# [40, 26, 9, -7]
# [40, 26, 9, 5]
# [40, 26, 9, 17]
# [40, 26, 9, 29]
# [40, 26, 21, 5]
# [40, 26, 21, 17]
# [40, 26, 21, 29]
# [40, 26, 21, 41]
# [40, 26, 33, 17]
# [40, 26, 33, 29]
# [40, 26, 33, 41]
# [40, 26, 33, 53]
# [40, 26, 45, 29]
# [40, 26, 45, 41]
# [40, 26, 45, 53]
# [40, 26, 45, 65]
# [40, 38, 21, 5]
# [40, 38, 21, 17]
# [40, 38, 21, 29]
# [40, 38, 21, 41]
# [40, 38, 33, 17]
# [40, 38, 33, 29]
# [40, 38, 33, 41]
# [40, 38, 33, 53]
# [40, 38, 45, 29]
# [40, 38, 45, 41]
# [40, 38, 45, 53]
# [40, 38, 45, 65]
# [40, 38, 57, 41]
# [40, 38, 57, 53]
# [40, 38, 57, 65]
# [40, 38, 57, 77]
# [40, 50, 33, 17]
# [40, 50, 33, 29]
# [40, 50, 33, 41]
# [40, 50, 33, 53]
# [40, 50, 45, 29]
# [40, 50, 45, 41]
# [40, 50, 45, 53]
# [40, 50, 45, 65]
# [40, 50, 57, 41]
# [40, 50, 57, 53]
# [40, 50, 57, 65]
# [40, 50, 57, 77]
# [40, 50, 69, 53]
# [40, 50, 69, 65]
# [40, 50, 69, 77]
# [40, 50, 69, 89]
# [40, 62, 45, 29]
# [40, 62, 45, 41]
# [40, 62, 45, 53]
# [40, 62, 45, 65]
# [40, 62, 57, 41]
# [40, 62, 57, 53]
# [40, 62, 57, 65]
# [40, 62, 57, 77]
# [40, 62, 69, 53]
# [40, 62, 69, 65]
# [40, 62, 69, 77]
# [40, 62, 69, 89]
# [40, 62, 81, 65]
# [40, 62, 81, 77]
# [40, 62, 81, 89]
# [40, 62, 81, 101]
# [40, 26, 9, -3]
# [40, 26, 9, 9]
# [40, 26, 9, 21]
# [40, 26, 21, 9]
# [40, 26, 21, 21]
# [40, 26, 21, 33]
# [40, 26, 33, 21]
# [40, 26, 33, 33]
# [40, 26, 33, 45]
# [40, 26, 45, 33]
# [40, 26, 45, 45]
# [40, 26, 45, 57]
# [40, 38, 21, 9]
# [40, 38, 21, 21]
# [40, 38, 21, 33]
# [40, 38, 33, 21]
# [40, 38, 33, 33]
# [40, 38, 33, 45]
# [40, 38, 45, 33]
# [40, 38, 45, 45]
# [40, 38, 45, 57]
# [40, 38, 57, 45]
# [40, 38, 57, 57]
# [40, 38, 57, 69]
# [40, 50, 33, 21]
# [40, 50, 33, 33]
# [40, 50, 33, 45]
# [40, 50, 45, 33]
# [40, 50, 45, 45]
# [40, 50, 45, 57]
# [40, 50, 57, 45]
# [40, 50, 57, 57]
# [40, 50, 57, 69]
# [40, 50, 69, 57]
# [40, 50, 69, 69]
# [40, 50, 69, 81]
# [40, 62, 45, 33]
# [40, 62, 45, 45]
# [40, 62, 45, 57]
# [40, 62, 57, 45]
# [40, 62, 57, 57]
# [40, 62, 57, 69]
# [40, 62, 69, 57]
# [40, 62, 69, 69]
# [40, 62, 69, 81]
# [40, 62, 81, 69]
# [40, 62, 81, 81]
# [40, 62, 81, 93]
# [40, 19, 0, -12]
# [40, 19, 0, 0]
# [40, 19, 0, 12]
# [40, 19, 12, 0]
# [40, 19, 12, 12]
# [40, 19, 12, 24]
# [40, 19, 24, 12]
# [40, 19, 24, 24]
# [40, 19, 24, 36]
# [40, 19, 36, 24]
# [40, 19, 36, 36]
# [40, 19, 36, 48]
# [40, 31, 12, 0]
# [40, 31, 12, 12]
# [40, 31, 12, 24]
# [40, 31, 24, 12]
# [40, 31, 24, 24]
# [40, 31, 24, 36]
# [40, 31, 36, 24]
# [40, 31, 36, 36]
# [40, 31, 36, 48]
# [40, 31, 48, 36]
# [40, 31, 48, 48]
# [40, 31, 48, 60]
# [40, 43, 24, 12]
# [40, 43, 24, 24]
# [40, 43, 24, 36]
# [40, 43, 36, 24]
# [40, 43, 36, 36]
# [40, 43, 36, 48]
# [40, 43, 48, 36]
# [40, 43, 48, 48]
# [40, 43, 48, 60]
# [40, 43, 60, 48]
# [40, 43, 60, 60]
# [40, 43, 60, 72]
# [40, 55, 36, 24]
# [40, 55, 36, 36]
# [40, 55, 36, 48]
# [40, 55, 48, 36]
# [40, 55, 48, 48]
# [40, 55, 48, 60]
# [40, 55, 60, 48]
# [40, 55, 60, 60]
# [40, 55, 60, 72]
# [40, 55, 72, 60]
# [40, 55, 72, 72]
# [40, 55, 72, 84]
# [40, 19, 0, -19]
# [40, 19, 0, -7]
# [40, 19, 0, 5]
# [40, 19, 0, 17]
# [40, 19, 12, -7]
# [40, 19, 12, 5]
# [40, 19, 12, 17]
# [40, 19, 12, 29]
# [40, 19, 24, 5]
# [40, 19, 24, 17]
# [40, 19, 24, 29]
# [40, 19, 24, 41]
# [40, 19, 36, 17]
# [40, 19, 36, 29]
# [40, 19, 36, 41]
# [40, 19, 36, 53]
# [40, 31, 12, -7]
# [40, 31, 12, 5]
# [40, 31, 12, 17]
# [40, 31, 12, 29]
# [40, 31, 24, 5]
# [40, 31, 24, 17]
# [40, 31, 24, 29]
# [40, 31, 24, 41]
# [40, 31, 36, 17]
# [40, 31, 36, 29]
# [40, 31, 36, 41]
# [40, 31, 36, 53]
# [40, 31, 48, 29]
# [40, 31, 48, 41]
# [40, 31, 48, 53]
# [40, 31, 48, 65]
# [40, 43, 24, 5]
# [40, 43, 24, 17]
# [40, 43, 24, 29]
# [40, 43, 24, 41]
# [40, 43, 36, 17]
# [40, 43, 36, 29]
# [40, 43, 36, 41]
# [40, 43, 36, 53]
# [40, 43, 48, 29]
# [40, 43, 48, 41]
# [40, 43, 48, 53]
# [40, 43, 48, 65]
# [40, 43, 60, 41]
# [40, 43, 60, 53]
# [40, 43, 60, 65]
# [40, 43, 60, 77]
# [40, 55, 36, 17]
# [40, 55, 36, 29]
# [40, 55, 36, 41]
# [40, 55, 36, 53]
# [40, 55, 48, 29]
# [40, 55, 48, 41]
# [40, 55, 48, 53]
# [40, 55, 48, 65]
# [40, 55, 60, 41]
# [40, 55, 60, 53]
# [40, 55, 60, 65]
# [40, 55, 60, 77]
# [40, 55, 72, 53]
# [40, 55, 72, 65]
# [40, 55, 72, 77]
# [40, 55, 72, 89]
# [40, 19, 0, -15]
# [40, 19, 0, -3]
# [40, 19, 0, 9]
# [40, 19, 0, 21]
# [40, 19, 12, -3]
# [40, 19, 12, 9]
# [40, 19, 12, 21]
# [40, 19, 12, 33]
# [40, 19, 24, 9]
# [40, 19, 24, 21]
# [40, 19, 24, 33]
# [40, 19, 24, 45]
# [40, 19, 36, 21]
# [40, 19, 36, 33]
# [40, 19, 36, 45]
# [40, 19, 36, 57]
# [40, 31, 12, -3]
# [40, 31, 12, 9]
# [40, 31, 12, 21]
# [40, 31, 12, 33]
# [40, 31, 24, 9]
# [40, 31, 24, 21]
# [40, 31, 24, 33]
# [40, 31, 24, 45]
# [40, 31, 36, 21]
# [40, 31, 36, 33]
# [40, 31, 36, 45]
# [40, 31, 36, 57]
# [40, 31, 48, 33]
# [40, 31, 48, 45]
# [40, 31, 48, 57]
# [40, 31, 48, 69]
# [40, 43, 24, 9]
# [40, 43, 24, 21]
# [40, 43, 24, 33]
# [40, 43, 24, 45]
# [40, 43, 36, 21]
# [40, 43, 36, 33]
# [40, 43, 36, 45]
# [40, 43, 36, 57]
# [40, 43, 48, 33]
# [40, 43, 48, 45]
# [40, 43, 48, 57]
# [40, 43, 48, 69]
# [40, 43, 60, 45]
# [40, 43, 60, 57]
# [40, 43, 60, 69]
# [40, 43, 60, 81]
# [40, 55, 36, 21]
# [40, 55, 36, 33]
# [40, 55, 36, 45]
# [40, 55, 36, 57]
# [40, 55, 48, 33]
# [40, 55, 48, 45]
# [40, 55, 48, 57]
# [40, 55, 48, 69]
# [40, 55, 60, 45]
# [40, 55, 60, 57]
# [40, 55, 60, 69]
# [40, 55, 60, 81]
# [40, 55, 72, 57]
# [40, 55, 72, 69]
# [40, 55, 72, 81]
# [40, 55, 72, 93]
# [40, 19, 4, -12]
# [40, 19, 4, 0]
# [40, 19, 4, 12]
# [40, 19, 4, 24]
# [40, 19, 16, 0]
# [40, 19, 16, 12]
# [40, 19, 16, 24]
# [40, 19, 16, 36]
# [40, 19, 28, 12]
# [40, 19, 28, 24]
# [40, 19, 28, 36]
# [40, 19, 28, 48]
# [40, 19, 40, 24]
# [40, 19, 40, 36]
# [40, 19, 40, 48]
# [40, 19, 40, 60]
# [40, 31, 16, 0]
# [40, 31, 16, 12]
# [40, 31, 16, 24]
# [40, 31, 16, 36]
# [40, 31, 28, 12]
# [40, 31, 28, 24]
# [40, 31, 28, 36]
# [40, 31, 28, 48]
# [40, 31, 40, 24]
# [40, 31, 40, 36]
# [40, 31, 40, 48]
# [40, 31, 40, 60]
# [40, 31, 52, 36]
# [40, 31, 52, 48]
# [40, 31, 52, 60]
# [40, 31, 52, 72]
# [40, 43, 28, 12]
# [40, 43, 28, 24]
# [40, 43, 28, 36]
# [40, 43, 28, 48]
# [40, 43, 40, 24]
# [40, 43, 40, 36]
# [40, 43, 40, 48]
# [40, 43, 40, 60]
# [40, 43, 52, 36]
# [40, 43, 52, 48]
# [40, 43, 52, 60]
# [40, 43, 52, 72]
# [40, 43, 64, 48]
# [40, 43, 64, 60]
# [40, 43, 64, 72]
# [40, 43, 64, 84]
# [40, 55, 40, 24]
# [40, 55, 40, 36]
# [40, 55, 40, 48]
# [40, 55, 40, 60]
# [40, 55, 52, 36]
# [40, 55, 52, 48]
# [40, 55, 52, 60]
# [40, 55, 52, 72]
# [40, 55, 64, 48]
# [40, 55, 64, 60]
# [40, 55, 64, 72]
# [40, 55, 64, 84]
# [40, 55, 76, 60]
# [40, 55, 76, 72]
# [40, 55, 76, 84]
# [40, 55, 76, 96]
# [40, 19, 4, -19]
# [40, 19, 4, -7]
# [40, 19, 4, 5]
# [40, 19, 4, 17]
# [40, 19, 16, -7]
# [40, 19, 16, 5]
# [40, 19, 16, 17]
# [40, 19, 16, 29]
# [40, 19, 28, 5]
# [40, 19, 28, 17]
# [40, 19, 28, 29]
# [40, 19, 28, 41]
# [40, 19, 40, 17]
# [40, 19, 40, 29]
# [40, 19, 40, 41]
# [40, 19, 40, 53]
# [40, 31, 16, -7]
# [40, 31, 16, 5]
# [40, 31, 16, 17]
# [40, 31, 16, 29]
# [40, 31, 28, 5]
# [40, 31, 28, 17]
# [40, 31, 28, 29]
# [40, 31, 28, 41]
# [40, 31, 40, 17]
# [40, 31, 40, 29]
# [40, 31, 40, 41]
# [40, 31, 40, 53]
# [40, 31, 52, 29]
# [40, 31, 52, 41]
# [40, 31, 52, 53]
# [40, 31, 52, 65]
# [40, 43, 28, 5]
# [40, 43, 28, 17]
# [40, 43, 28, 29]
# [40, 43, 28, 41]
# [40, 43, 40, 17]
# [40, 43, 40, 29]
# [40, 43, 40, 41]
# [40, 43, 40, 53]
# [40, 43, 52, 29]
# [40, 43, 52, 41]
# [40, 43, 52, 53]
# [40, 43, 52, 65]
# [40, 43, 64, 41]
# [40, 43, 64, 53]
# [40, 43, 64, 65]
# [40, 43, 64, 77]
# [40, 55, 40, 17]
# [40, 55, 40, 29]
# [40, 55, 40, 41]
# [40, 55, 40, 53]
# [40, 55, 52, 29]
# [40, 55, 52, 41]
# [40, 55, 52, 53]
# [40, 55, 52, 65]
# [40, 55, 64, 41]
# [40, 55, 64, 53]
# [40, 55, 64, 65]
# [40, 55, 64, 77]
# [40, 55, 76, 53]
# [40, 55, 76, 65]
# [40, 55, 76, 77]
# [40, 55, 76, 89]
# [40, 19, 4, -15]
# [40, 19, 4, -3]
# [40, 19, 4, 9]
# [40, 19, 4, 21]
# [40, 19, 16, -3]
# [40, 19, 16, 9]
# [40, 19, 16, 21]
# [40, 19, 16, 33]
# [40, 19, 28, 9]
# [40, 19, 28, 21]
# [40, 19, 28, 33]
# [40, 19, 28, 45]
# [40, 19, 40, 21]
# [40, 19, 40, 33]
# [40, 19, 40, 45]
# [40, 19, 40, 57]
# [40, 31, 16, -3]
# [40, 31, 16, 9]
# [40, 31, 16, 21]
# [40, 31, 16, 33]
# [40, 31, 28, 9]
# [40, 31, 28, 21]
# [40, 31, 28, 33]
# [40, 31, 28, 45]
# [40, 31, 40, 21]
# [40, 31, 40, 33]
# [40, 31, 40, 45]
# [40, 31, 40, 57]
# [40, 31, 52, 33]
# [40, 31, 52, 45]
# [40, 31, 52, 57]
# [40, 31, 52, 69]
# [40, 43, 28, 9]
# [40, 43, 28, 21]
# [40, 43, 28, 33]
# [40, 43, 28, 45]
# [40, 43, 40, 21]
# [40, 43, 40, 33]
# [40, 43, 40, 45]
# [40, 43, 40, 57]
# [40, 43, 52, 33]
# [40, 43, 52, 45]
# [40, 43, 52, 57]
# [40, 43, 52, 69]
# [40, 43, 64, 45]
# [40, 43, 64, 57]
# [40, 43, 64, 69]
# [40, 43, 64, 81]
# [40, 55, 40, 21]
# [40, 55, 40, 33]
# [40, 55, 40, 45]
# [40, 55, 40, 57]
# [40, 55, 52, 33]
# [40, 55, 52, 45]
# [40, 55, 52, 57]
# [40, 55, 52, 69]
# [40, 55, 64, 45]
# [40, 55, 64, 57]
# [40, 55, 64, 69]
# [40, 55, 64, 81]
# [40, 55, 76, 57]
# [40, 55, 76, 69]
# [40, 55, 76, 81]
# [40, 55, 76, 93]
# [40, 19, -3, -24]
# [40, 19, -3, -12]
# [40, 19, -3, 0]
# [40, 19, -3, 12]
# [40, 19, 9, -12]
# [40, 19, 9, 0]
# [40, 19, 9, 12]
# [40, 19, 9, 24]
# [40, 19, 21, 0]
# [40, 19, 21, 12]
# [40, 19, 21, 24]
# [40, 19, 21, 36]
# [40, 19, 33, 12]
# [40, 19, 33, 24]
# [40, 19, 33, 36]
# [40, 19, 33, 48]
# [40, 31, 9, -12]
# [40, 31, 9, 0]
# [40, 31, 9, 12]
# [40, 31, 9, 24]
# [40, 31, 21, 0]
# [40, 31, 21, 12]
# [40, 31, 21, 24]
# [40, 31, 21, 36]
# [40, 31, 33, 12]
# [40, 31, 33, 24]
# [40, 31, 33, 36]
# [40, 31, 33, 48]
# [40, 31, 45, 24]
# [40, 31, 45, 36]
# [40, 31, 45, 48]
# [40, 31, 45, 60]
# [40, 43, 21, 0]
# [40, 43, 21, 12]
# [40, 43, 21, 24]
# [40, 43, 21, 36]
# [40, 43, 33, 12]
# [40, 43, 33, 24]
# [40, 43, 33, 36]
# [40, 43, 33, 48]
# [40, 43, 45, 24]
# [40, 43, 45, 36]
# [40, 43, 45, 48]
# [40, 43, 45, 60]
# [40, 43, 57, 36]
# [40, 43, 57, 48]
# [40, 43, 57, 60]
# [40, 43, 57, 72]
# [40, 55, 33, 12]
# [40, 55, 33, 24]
# [40, 55, 33, 36]
# [40, 55, 33, 48]
# [40, 55, 45, 24]
# [40, 55, 45, 36]
# [40, 55, 45, 48]
# [40, 55, 45, 60]
# [40, 55, 57, 36]
# [40, 55, 57, 48]
# [40, 55, 57, 60]
# [40, 55, 57, 72]
# [40, 55, 69, 48]
# [40, 55, 69, 60]
# [40, 55, 69, 72]
# [40, 55, 69, 84]
# [40, 19, -3, -19]
# [40, 19, -3, -7]
# [40, 19, -3, 5]
# [40, 19, -3, 17]
# [40, 19, 9, -7]
# [40, 19, 9, 5]
# [40, 19, 9, 17]
# [40, 19, 9, 29]
# [40, 19, 21, 5]
# [40, 19, 21, 17]
# [40, 19, 21, 29]
# [40, 19, 21, 41]
# [40, 19, 33, 17]
# [40, 19, 33, 29]
# [40, 19, 33, 41]
# [40, 19, 33, 53]
# [40, 31, 9, -7]
# [40, 31, 9, 5]
# [40, 31, 9, 17]
# [40, 31, 9, 29]
# [40, 31, 21, 5]
# [40, 31, 21, 17]
# [40, 31, 21, 29]
# [40, 31, 21, 41]
# [40, 31, 33, 17]
# [40, 31, 33, 29]
# [40, 31, 33, 41]
# [40, 31, 33, 53]
# [40, 31, 45, 29]
# [40, 31, 45, 41]
# [40, 31, 45, 53]
# [40, 31, 45, 65]
# [40, 43, 21, 5]
# [40, 43, 21, 17]
# [40, 43, 21, 29]
# [40, 43, 21, 41]
# [40, 43, 33, 17]
# [40, 43, 33, 29]
# [40, 43, 33, 41]
# [40, 43, 33, 53]
# [40, 43, 45, 29]
# [40, 43, 45, 41]
# [40, 43, 45, 53]
# [40, 43, 45, 65]
# [40, 43, 57, 41]
# [40, 43, 57, 53]
# [40, 43, 57, 65]
# [40, 43, 57, 77]
# [40, 55, 33, 17]
# [40, 55, 33, 29]
# [40, 55, 33, 41]
# [40, 55, 33, 53]
# [40, 55, 45, 29]
# [40, 55, 45, 41]
# [40, 55, 45, 53]
# [40, 55, 45, 65]
# [40, 55, 57, 41]
# [40, 55, 57, 53]
# [40, 55, 57, 65]
# [40, 55, 57, 77]
# [40, 55, 69, 53]
# [40, 55, 69, 65]
# [40, 55, 69, 77]
# [40, 55, 69, 89]
# [40, 19, -3, -15]
# [40, 19, -3, -3]
# [40, 19, -3, 9]
# [40, 19, 9, -3]
# [40, 19, 9, 9]
# [40, 19, 9, 21]
# [40, 19, 21, 9]
# [40, 19, 21, 21]
# [40, 19, 21, 33]
# [40, 19, 33, 21]
# [40, 19, 33, 33]
# [40, 19, 33, 45]
# [40, 31, 9, -3]
# [40, 31, 9, 9]
# [40, 31, 9, 21]
# [40, 31, 21, 9]
# [40, 31, 21, 21]
# [40, 31, 21, 33]
# [40, 31, 33, 21]
# [40, 31, 33, 33]
# [40, 31, 33, 45]
# [40, 31, 45, 33]
# [40, 31, 45, 45]
# [40, 31, 45, 57]
# [40, 43, 21, 9]
# [40, 43, 21, 21]
# [40, 43, 21, 33]
# [40, 43, 33, 21]
# [40, 43, 33, 33]
# [40, 43, 33, 45]
# [40, 43, 45, 33]
# [40, 43, 45, 45]
# [40, 43, 45, 57]
# [40, 43, 57, 45]
# [40, 43, 57, 57]
# [40, 43, 57, 69]
# [40, 55, 33, 21]
# [40, 55, 33, 33]
# [40, 55, 33, 45]
# [40, 55, 45, 33]
# [40, 55, 45, 45]
# [40, 55, 45, 57]
# [40, 55, 57, 45]
# [40, 55, 57, 57]
# [40, 55, 57, 69]
# [40, 55, 69, 57]
# [40, 55, 69, 69]
# [40, 55, 69, 81]
# [40, 23, 0, -12]
# [40, 23, 0, 0]
# [40, 23, 0, 12]
# [40, 23, 12, 0]
# [40, 23, 12, 12]
# [40, 23, 12, 24]
# [40, 23, 24, 12]
# [40, 23, 24, 24]
# [40, 23, 24, 36]
# [40, 23, 36, 24]
# [40, 23, 36, 36]
# [40, 23, 36, 48]
# [40, 35, 12, 0]
# [40, 35, 12, 12]
# [40, 35, 12, 24]
# [40, 35, 24, 12]
# [40, 35, 24, 24]
# [40, 35, 24, 36]
# [40, 35, 36, 24]
# [40, 35, 36, 36]
# [40, 35, 36, 48]
# [40, 35, 48, 36]
# [40, 35, 48, 48]
# [40, 35, 48, 60]
# [40, 47, 24, 12]
# [40, 47, 24, 24]
# [40, 47, 24, 36]
# [40, 47, 36, 24]
# [40, 47, 36, 36]
# [40, 47, 36, 48]
# [40, 47, 48, 36]
# [40, 47, 48, 48]
# [40, 47, 48, 60]
# [40, 47, 60, 48]
# [40, 47, 60, 60]
# [40, 47, 60, 72]
# [40, 59, 36, 24]
# [40, 59, 36, 36]
# [40, 59, 36, 48]
# [40, 59, 48, 36]
# [40, 59, 48, 48]
# [40, 59, 48, 60]
# [40, 59, 60, 48]
# [40, 59, 60, 60]
# [40, 59, 60, 72]
# [40, 59, 72, 60]
# [40, 59, 72, 72]
# [40, 59, 72, 84]
# [40, 23, 0, -19]
# [40, 23, 0, -7]
# [40, 23, 0, 5]
# [40, 23, 0, 17]
# [40, 23, 12, -7]
# [40, 23, 12, 5]
# [40, 23, 12, 17]
# [40, 23, 12, 29]
# [40, 23, 24, 5]
# [40, 23, 24, 17]
# [40, 23, 24, 29]
# [40, 23, 24, 41]
# [40, 23, 36, 17]
# [40, 23, 36, 29]
# [40, 23, 36, 41]
# [40, 23, 36, 53]
# [40, 35, 12, -7]
# [40, 35, 12, 5]
# [40, 35, 12, 17]
# [40, 35, 12, 29]
# [40, 35, 24, 5]
# [40, 35, 24, 17]
# [40, 35, 24, 29]
# [40, 35, 24, 41]
# [40, 35, 36, 17]
# [40, 35, 36, 29]
# [40, 35, 36, 41]
# [40, 35, 36, 53]
# [40, 35, 48, 29]
# [40, 35, 48, 41]
# [40, 35, 48, 53]
# [40, 35, 48, 65]
# [40, 47, 24, 5]
# [40, 47, 24, 17]
# [40, 47, 24, 29]
# [40, 47, 24, 41]
# [40, 47, 36, 17]
# [40, 47, 36, 29]
# [40, 47, 36, 41]
# [40, 47, 36, 53]
# [40, 47, 48, 29]
# [40, 47, 48, 41]
# [40, 47, 48, 53]
# [40, 47, 48, 65]
# [40, 47, 60, 41]
# [40, 47, 60, 53]
# [40, 47, 60, 65]
# [40, 47, 60, 77]
# [40, 59, 36, 17]
# [40, 59, 36, 29]
# [40, 59, 36, 41]
# [40, 59, 36, 53]
# [40, 59, 48, 29]
# [40, 59, 48, 41]
# [40, 59, 48, 53]
# [40, 59, 48, 65]
# [40, 59, 60, 41]
# [40, 59, 60, 53]
# [40, 59, 60, 65]
# [40, 59, 60, 77]
# [40, 59, 72, 53]
# [40, 59, 72, 65]
# [40, 59, 72, 77]
# [40, 59, 72, 89]
# [40, 23, 0, -15]
# [40, 23, 0, -3]
# [40, 23, 0, 9]
# [40, 23, 0, 21]
# [40, 23, 12, -3]
# [40, 23, 12, 9]
# [40, 23, 12, 21]
# [40, 23, 12, 33]
# [40, 23, 24, 9]
# [40, 23, 24, 21]
# [40, 23, 24, 33]
# [40, 23, 24, 45]
# [40, 23, 36, 21]
# [40, 23, 36, 33]
# ...
# [43, 31, 36, 24]
# [43, 31, 36, 36]
# [43, 31, 36, 48]
# [43, 31, 48, 36]
# [43, 31, 48, 48]
# [43, 31, 48, 60]
# [43, 43, 24, 12]
# [43, 43, 24, 24]
# [43, 43, 24, 36]
# [43, 43, 36, 24]
# [43, 43, 36, 36]
# [43, 43, 36, 48]
# [43, 43, 48, 36]
# [43, 43, 48, 48]
# [43, 43, 48, 60]
# [43, 43, 60, 48]
# [43, 43, 60, 60]
# [43, 43, 60, 72]
# [43, 55, 36, 24]
# [43, 55, 36, 36]
# [43, 55, 36, 48]
# [43, 55, 48, 36]
# [43, 55, 48, 48]
# [43, 55, 48, 60]
# [43, 55, 60, 48]
# [43, 55, 60, 60]
# [43, 55, 60, 72]
# [43, 55, 72, 60]
# [43, 55, 72, 72]
# [43, 55, 72, 84]
# [43, 31, 12, -7]
# [43, 31, 12, 5]
# [43, 31, 12, 17]
# [43, 31, 12, 29]
# [43, 31, 24, 5]
# [43, 31, 24, 17]
# [43, 31, 24, 29]
# [43, 31, 24, 41]
# [43, 31, 36, 17]
# [43, 31, 36, 29]
# [43, 31, 36, 41]
# [43, 31, 36, 53]
# [43, 31, 48, 29]
# [43, 31, 48, 41]
# [43, 31, 48, 53]
# [43, 31, 48, 65]
# [43, 43, 24, 5]
# [43, 43, 24, 17]
# [43, 43, 24, 29]
# [43, 43, 24, 41]
# [43, 43, 36, 17]
# [43, 43, 36, 29]
# [43, 43, 36, 41]
# [43, 43, 36, 53]
# [43, 43, 48, 29]
# [43, 43, 48, 41]
# [43, 43, 48, 53]
# [43, 43, 48, 65]
# [43, 43, 60, 41]
# [43, 43, 60, 53]
# [43, 43, 60, 65]
# [43, 43, 60, 77]
# [43, 55, 36, 17]
# [43, 55, 36, 29]
# [43, 55, 36, 41]
# [43, 55, 36, 53]
# [43, 55, 48, 29]
# [43, 55, 48, 41]
# [43, 55, 48, 53]
# [43, 55, 48, 65]
# [43, 55, 60, 41]
# [43, 55, 60, 53]
# [43, 55, 60, 65]
# [43, 55, 60, 77]
# [43, 55, 72, 53]
# [43, 55, 72, 65]
# [43, 55, 72, 77]
# [43, 55, 72, 89]
# [43, 31, 12, -3]
# [43, 31, 12, 9]
# [43, 31, 12, 21]
# [43, 31, 12, 33]
# [43, 31, 24, 9]
# [43, 31, 24, 21]
# [43, 31, 24, 33]
# [43, 31, 24, 45]
# [43, 31, 36, 21]
# [43, 31, 36, 33]
# [43, 31, 36, 45]
# [43, 31, 36, 57]
# [43, 31, 48, 33]
# [43, 31, 48, 45]
# [43, 31, 48, 57]
# [43, 31, 48, 69]
# [43, 43, 24, 9]
# [43, 43, 24, 21]
# [43, 43, 24, 33]
# [43, 43, 24, 45]
# [43, 43, 36, 21]
# [43, 43, 36, 33]
# [43, 43, 36, 45]
# [43, 43, 36, 57]
# [43, 43, 48, 33]
# [43, 43, 48, 45]
# [43, 43, 48, 57]
# [43, 43, 48, 69]
# [43, 43, 60, 45]
# [43, 43, 60, 57]
# [43, 43, 60, 69]
# [43, 43, 60, 81]
# [43, 55, 36, 21]
# [43, 55, 36, 33]
# [43, 55, 36, 45]
# [43, 55, 36, 57]
# [43, 55, 48, 33]
# [43, 55, 48, 45]
# [43, 55, 48, 57]
# [43, 55, 48, 69]
# [43, 55, 60, 45]
# [43, 55, 60, 57]
# [43, 55, 60, 69]
# [43, 55, 60, 81]
# [43, 55, 72, 57]
# [43, 55, 72, 69]
# [43, 55, 72, 81]
# [43, 55, 72, 93]
# [43, 31, 16, 0]
# [43, 31, 16, 12]
# [43, 31, 16, 24]
# [43, 31, 16, 36]
# [43, 31, 28, 12]
# [43, 31, 28, 24]
# [43, 31, 28, 36]
# [43, 31, 28, 48]
# [43, 31, 40, 24]
# [43, 31, 40, 36]
# [43, 31, 40, 48]
# [43, 31, 40, 60]
# [43, 31, 52, 36]
# [43, 31, 52, 48]
# [43, 31, 52, 60]
# [43, 31, 52, 72]
# [43, 43, 28, 12]
# [43, 43, 28, 24]
# [43, 43, 28, 36]
# [43, 43, 28, 48]
# [43, 43, 40, 24]
# [43, 43, 40, 36]
# [43, 43, 40, 48]
# [43, 43, 40, 60]
# [43, 43, 52, 36]
# [43, 43, 52, 48]
# [43, 43, 52, 60]
# [43, 43, 52, 72]
# [43, 43, 64, 48]
# [43, 43, 64, 60]
# [43, 43, 64, 72]
# [43, 43, 64, 84]
# [43, 55, 40, 24]
# [43, 55, 40, 36]
# [43, 55, 40, 48]
# [43, 55, 40, 60]
# [43, 55, 52, 36]
# [43, 55, 52, 48]
# [43, 55, 52, 60]
# [43, 55, 52, 72]
# [43, 55, 64, 48]
# [43, 55, 64, 60]
# [43, 55, 64, 72]
# [43, 55, 64, 84]
# [43, 55, 76, 60]
# [43, 55, 76, 72]
# [43, 55, 76, 84]
# [43, 55, 76, 96]
# [43, 31, 16, -7]
# [43, 31, 16, 5]
# [43, 31, 16, 17]
# [43, 31, 16, 29]
# [43, 31, 28, 5]
# [43, 31, 28, 17]
# [43, 31, 28, 29]
# [43, 31, 28, 41]
# [43, 31, 40, 17]
# [43, 31, 40, 29]
# [43, 31, 40, 41]
# [43, 31, 40, 53]
# [43, 31, 52, 29]
# [43, 31, 52, 41]
# [43, 31, 52, 53]
# [43, 31, 52, 65]
# [43, 43, 28, 5]
# [43, 43, 28, 17]
# [43, 43, 28, 29]
# [43, 43, 28, 41]
# [43, 43, 40, 17]
# [43, 43, 40, 29]
# [43, 43, 40, 41]
# [43, 43, 40, 53]
# [43, 43, 52, 29]
# [43, 43, 52, 41]
# [43, 43, 52, 53]
# [43, 43, 52, 65]
# [43, 43, 64, 41]
# [43, 43, 64, 53]
# [43, 43, 64, 65]
# [43, 43, 64, 77]
# [43, 55, 40, 17]
# [43, 55, 40, 29]
# [43, 55, 40, 41]
# [43, 55, 40, 53]
# [43, 55, 52, 29]
# [43, 55, 52, 41]
# [43, 55, 52, 53]
# [43, 55, 52, 65]
# [43, 55, 64, 41]
# [43, 55, 64, 53]
# [43, 55, 64, 65]
# [43, 55, 64, 77]
# [43, 55, 76, 53]
# [43, 55, 76, 65]
# [43, 55, 76, 77]
# [43, 55, 76, 89]
# [43, 31, 16, -3]
# [43, 31, 16, 9]
# [43, 31, 16, 21]
# [43, 31, 16, 33]
# [43, 31, 28, 9]
# [43, 31, 28, 21]
# [43, 31, 28, 33]
# [43, 31, 28, 45]
# [43, 31, 40, 21]
# [43, 31, 40, 33]
# [43, 31, 40, 45]
# [43, 31, 40, 57]
# [43, 31, 52, 33]
# [43, 31, 52, 45]
# [43, 31, 52, 57]
# [43, 31, 52, 69]
# [43, 43, 28, 9]
# [43, 43, 28, 21]
# [43, 43, 28, 33]
# [43, 43, 28, 45]
# [43, 43, 40, 21]
# [43, 43, 40, 33]
# [43, 43, 40, 45]
# [43, 43, 40, 57]
# [43, 43, 52, 33]
# [43, 43, 52, 45]
# [43, 43, 52, 57]
# [43, 43, 52, 69]
# [43, 43, 64, 45]
# [43, 43, 64, 57]
# [43, 43, 64, 69]
# [43, 43, 64, 81]
# [43, 55, 40, 21]
# [43, 55, 40, 33]
# [43, 55, 40, 45]
# [43, 55, 40, 57]
# [43, 55, 52, 33]
# [43, 55, 52, 45]
# [43, 55, 52, 57]
# [43, 55, 52, 69]
# [43, 55, 64, 45]
# [43, 55, 64, 57]
# [43, 55, 64, 69]
# [43, 55, 64, 81]
# [43, 55, 76, 57]
# [43, 55, 76, 69]
# [43, 55, 76, 81]
# [43, 55, 76, 93]
# [43, 31, 9, -12]
# [43, 31, 9, 0]
# [43, 31, 9, 12]
# [43, 31, 9, 24]
# [43, 31, 21, 0]
# [43, 31, 21, 12]
# [43, 31, 21, 24]
# [43, 31, 21, 36]
# [43, 31, 33, 12]
# [43, 31, 33, 24]
# [43, 31, 33, 36]
# [43, 31, 33, 48]
# [43, 31, 45, 24]
# [43, 31, 45, 36]
# [43, 31, 45, 48]
# [43, 31, 45, 60]
# [43, 43, 21, 0]
# [43, 43, 21, 12]
# [43, 43, 21, 24]
# [43, 43, 21, 36]
# [43, 43, 33, 12]
# [43, 43, 33, 24]
# [43, 43, 33, 36]
# [43, 43, 33, 48]
# [43, 43, 45, 24]
# [43, 43, 45, 36]
# [43, 43, 45, 48]
# [43, 43, 45, 60]
# [43, 43, 57, 36]
# [43, 43, 57, 48]
# [43, 43, 57, 60]
# [43, 43, 57, 72]
# [43, 55, 33, 12]
# [43, 55, 33, 24]
# [43, 55, 33, 36]
# [43, 55, 33, 48]
# [43, 55, 45, 24]
# [43, 55, 45, 36]
# [43, 55, 45, 48]
# [43, 55, 45, 60]
# [43, 55, 57, 36]
# [43, 55, 57, 48]
# [43, 55, 57, 60]
# [43, 55, 57, 72]
# [43, 55, 69, 48]
# [43, 55, 69, 60]
# [43, 55, 69, 72]
# [43, 55, 69, 84]
# [43, 31, 9, -7]
# [43, 31, 9, 5]
# [43, 31, 9, 17]
# [43, 31, 9, 29]
# [43, 31, 21, 5]
# [43, 31, 21, 17]
# [43, 31, 21, 29]
# [43, 31, 21, 41]
# [43, 31, 33, 17]
# [43, 31, 33, 29]
# [43, 31, 33, 41]
# [43, 31, 33, 53]
# [43, 31, 45, 29]
# [43, 31, 45, 41]
# [43, 31, 45, 53]
# [43, 31, 45, 65]
# [43, 43, 21, 5]
# [43, 43, 21, 17]
# [43, 43, 21, 29]
# [43, 43, 21, 41]
# [43, 43, 33, 17]
# [43, 43, 33, 29]
# [43, 43, 33, 41]
# [43, 43, 33, 53]
# [43, 43, 45, 29]
# [43, 43, 45, 41]
# [43, 43, 45, 53]
# [43, 43, 45, 65]
# [43, 43, 57, 41]
# [43, 43, 57, 53]
# [43, 43, 57, 65]
# [43, 43, 57, 77]
# [43, 55, 33, 17]
# [43, 55, 33, 29]
# [43, 55, 33, 41]
# [43, 55, 33, 53]
# [43, 55, 45, 29]
# [43, 55, 45, 41]
# [43, 55, 45, 53]
# [43, 55, 45, 65]
# [43, 55, 57, 41]
# [43, 55, 57, 53]
# [43, 55, 57, 65]
# [43, 55, 57, 77]
# [43, 55, 69, 53]
# [43, 55, 69, 65]
# [43, 55, 69, 77]
# [43, 55, 69, 89]
# [43, 31, 9, -3]
# [43, 31, 9, 9]
# [43, 31, 9, 21]
# [43, 31, 21, 9]
# [43, 31, 21, 21]
# [43, 31, 21, 33]
# [43, 31, 33, 21]
# [43, 31, 33, 33]
# [43, 31, 33, 45]
# [43, 31, 45, 33]
# [43, 31, 45, 45]
# [43, 31, 45, 57]
# [43, 43, 21, 9]
# [43, 43, 21, 21]
# [43, 43, 21, 33]
# [43, 43, 33, 21]
# [43, 43, 33, 33]
# [43, 43, 33, 45]
# [43, 43, 45, 33]
# [43, 43, 45, 45]
# [43, 43, 45, 57]
# [43, 43, 57, 45]
# [43, 43, 57, 57]
# [43, 43, 57, 69]
# [43, 55, 33, 21]
# [43, 55, 33, 33]
# [43, 55, 33, 45]
# [43, 55, 45, 33]
# [43, 55, 45, 45]
# [43, 55, 45, 57]
# [43, 55, 57, 45]
# [43, 55, 57, 57]
# [43, 55, 57, 69]
# [43, 55, 69, 57]
# [43, 55, 69, 69]
# [43, 55, 69, 81]
# [43, 23, 0, -12]
# [43, 23, 0, 0]
# [43, 23, 0, 12]
# [43, 23, 12, 0]
# [43, 23, 12, 12]
# [43, 23, 12, 24]
# [43, 23, 24, 12]
# [43, 23, 24, 24]
# [43, 23, 24, 36]
# [43, 23, 36, 24]
# [43, 23, 36, 36]
# [43, 23, 36, 48]
# [43, 35, 12, 0]
# [43, 35, 12, 12]
# [43, 35, 12, 24]
# [43, 35, 24, 12]
# [43, 35, 24, 24]
# [43, 35, 24, 36]
# [43, 35, 36, 24]
# [43, 35, 36, 36]
# [43, 35, 36, 48]
# [43, 35, 48, 36]
# [43, 35, 48, 48]
# [43, 35, 48, 60]
# [43, 47, 24, 12]
# [43, 47, 24, 24]
# [43, 47, 24, 36]
# [43, 47, 36, 24]
# [43, 47, 36, 36]
# [43, 47, 36, 48]
# [43, 47, 48, 36]
# [43, 47, 48, 48]
# [43, 47, 48, 60]
# [43, 47, 60, 48]
# [43, 47, 60, 60]
# [43, 47, 60, 72]
# [43, 59, 36, 24]
# [43, 59, 36, 36]
# [43, 59, 36, 48]
# [43, 59, 48, 36]
# [43, 59, 48, 48]
# [43, 59, 48, 60]
# [43, 59, 60, 48]
# [43, 59, 60, 60]
# [43, 59, 60, 72]
# [43, 59, 72, 60]
# [43, 59, 72, 72]
# [43, 59, 72, 84]
# [43, 23, 0, -19]
# [43, 23, 0, -7]
# [43, 23, 0, 5]
# [43, 23, 0, 17]
# [43, 23, 12, -7]
# [43, 23, 12, 5]
# [43, 23, 12, 17]
# [43, 23, 12, 29]
# [43, 23, 24, 5]
# [43, 23, 24, 17]
# [43, 23, 24, 29]
# [43, 23, 24, 41]
# [43, 23, 36, 17]
# [43, 23, 36, 29]
# [43, 23, 36, 41]
# [43, 23, 36, 53]
# [43, 35, 12, -7]
# [43, 35, 12, 5]
# [43, 35, 12, 17]
# [43, 35, 12, 29]
# [43, 35, 24, 5]
# [43, 35, 24, 17]
# [43, 35, 24, 29]
# [43, 35, 24, 41]
# [43, 35, 36, 17]
# [43, 35, 36, 29]
# [43, 35, 36, 41]
# [43, 35, 36, 53]
# [43, 35, 48, 29]
# [43, 35, 48, 41]
# [43, 35, 48, 53]
# [43, 35, 48, 65]
# [43, 47, 24, 5]
# [43, 47, 24, 17]
# [43, 47, 24, 29]
# [43, 47, 24, 41]
# [43, 47, 36, 17]
# [43, 47, 36, 29]
# [43, 47, 36, 41]
# [43, 47, 36, 53]
# [43, 47, 48, 29]
# [43, 47, 48, 41]
# [43, 47, 48, 53]
# [43, 47, 48, 65]
# [43, 47, 60, 41]
# [43, 47, 60, 53]
# [43, 47, 60, 65]
# [43, 47, 60, 77]
# [43, 59, 36, 17]
# [43, 59, 36, 29]
# [43, 59, 36, 41]
# [43, 59, 36, 53]
# [43, 59, 48, 29]
# [43, 59, 48, 41]
# [43, 59, 48, 53]
# [43, 59, 48, 65]
# [43, 59, 60, 41]
# [43, 59, 60, 53]
# [43, 59, 60, 65]
# [43, 59, 60, 77]
# [43, 59, 72, 53]
# [43, 59, 72, 65]
# [43, 59, 72, 77]
# [43, 59, 72, 89]
# [43, 23, 0, -15]
# [43, 23, 0, -3]
# [43, 23, 0, 9]
# [43, 23, 0, 21]
# [43, 23, 12, -3]
# [43, 23, 12, 9]
# [43, 23, 12, 21]
# [43, 23, 12, 33]
# [43, 23, 24, 9]
# [43, 23, 24, 21]
# [43, 23, 24, 33]
# [43, 23, 24, 45]
# [43, 23, 36, 21]
# [43, 23, 36, 33]
# [43, 23, 36, 45]
# [43, 23, 36, 57]
# [43, 35, 12, -3]
# [43, 35, 12, 9]
# [43, 35, 12, 21]
# [43, 35, 12, 33]
# [43, 35, 24, 9]
# [43, 35, 24, 21]
# [43, 35, 24, 33]
# [43, 35, 24, 45]
# [43, 35, 36, 21]
# [43, 35, 36, 33]
# [43, 35, 36, 45]
# [43, 35, 36, 57]
# [43, 35, 48, 33]
# [43, 35, 48, 45]
# [43, 35, 48, 57]
# [43, 35, 48, 69]
# [43, 47, 24, 9]
# [43, 47, 24, 21]
# [43, 47, 24, 33]
# [43, 47, 24, 45]
# [43, 47, 36, 21]
# [43, 47, 36, 33]
# [43, 47, 36, 45]
# [43, 47, 36, 57]
# [43, 47, 48, 33]
# [43, 47, 48, 45]
# [43, 47, 48, 57]
# [43, 47, 48, 69]
# [43, 47, 60, 45]
# [43, 47, 60, 57]
# [43, 47, 60, 69]
# [43, 47, 60, 81]
# [43, 59, 36, 21]
# [43, 59, 36, 33]
# [43, 59, 36, 45]
# [43, 59, 36, 57]
# [43, 59, 48, 33]
# [43, 59, 48, 45]
# [43, 59, 48, 57]
# [43, 59, 48, 69]
# [43, 59, 60, 45]
# [43, 59, 60, 57]
# [43, 59, 60, 69]
# [43, 59, 60, 81]
# [43, 59, 72, 57]
# [43, 59, 72, 69]
# [43, 59, 72, 81]
# [43, 59, 72, 93]
# [43, 23, 4, -12]
# [43, 23, 4, 0]
# [43, 23, 4, 12]
# [43, 23, 4, 24]
# [43, 23, 16, 0]
# [43, 23, 16, 12]
# [43, 23, 16, 24]
# [43, 23, 16, 36]
# [43, 23, 28, 12]
# [43, 23, 28, 24]
# [43, 23, 28, 36]
# [43, 23, 28, 48]
# [43, 23, 40, 24]
# [43, 23, 40, 36]
# [43, 23, 40, 48]
# [43, 23, 40, 60]
# [43, 35, 16, 0]
# [43, 35, 16, 12]
# [43, 35, 16, 24]
# [43, 35, 16, 36]
# [43, 35, 28, 12]
# [43, 35, 28, 24]
# [43, 35, 28, 36]
# [43, 35, 28, 48]
# [43, 35, 40, 24]
# [43, 35, 40, 36]
# [43, 35, 40, 48]
# [43, 35, 40, 60]
# [43, 35, 52, 36]
# [43, 35, 52, 48]
# [43, 35, 52, 60]
# [43, 35, 52, 72]
# [43, 47, 28, 12]
# [43, 47, 28, 24]
# [43, 47, 28, 36]
# [43, 47, 28, 48]
# [43, 47, 40, 24]
# [43, 47, 40, 36]
# [43, 47, 40, 48]
# [43, 47, 40, 60]
# [43, 47, 52, 36]
# [43, 47, 52, 48]
# [43, 47, 52, 60]
# [43, 47, 52, 72]
# [43, 47, 64, 48]
# [43, 47, 64, 60]
# [43, 47, 64, 72]
# [43, 47, 64, 84]
# [43, 59, 40, 24]
# [43, 59, 40, 36]
# [43, 59, 40, 48]
# [43, 59, 40, 60]
# [43, 59, 52, 36]
# [43, 59, 52, 48]
# [43, 59, 52, 60]
# [43, 59, 52, 72]
# [43, 59, 64, 48]
# [43, 59, 64, 60]
# [43, 59, 64, 72]
# [43, 59, 64, 84]
# [43, 59, 76, 60]
# [43, 59, 76, 72]
# [43, 59, 76, 84]
# [43, 59, 76, 96]
# [43, 23, 4, -19]
# [43, 23, 4, -7]
# [43, 23, 4, 5]
# [43, 23, 4, 17]
# [43, 23, 16, -7]
# [43, 23, 16, 5]
# [43, 23, 16, 17]
# [43, 23, 16, 29]
# [43, 23, 28, 5]
# [43, 23, 28, 17]
# [43, 23, 28, 29]
# [43, 23, 28, 41]
# [43, 23, 40, 17]
# [43, 23, 40, 29]
# [43, 23, 40, 41]
# [43, 23, 40, 53]
# [43, 35, 16, -7]
# [43, 35, 16, 5]
# [43, 35, 16, 17]
# [43, 35, 16, 29]
# [43, 35, 28, 5]
# [43, 35, 28, 17]
# [43, 35, 28, 29]
# [43, 35, 28, 41]
# [43, 35, 40, 17]
# [43, 35, 40, 29]
# [43, 35, 40, 41]
# [43, 35, 40, 53]
# [43, 35, 52, 29]
# [43, 35, 52, 41]
# [43, 35, 52, 53]
# [43, 35, 52, 65]
# [43, 47, 28, 5]
# [43, 47, 28, 17]
# [43, 47, 28, 29]
# [43, 47, 28, 41]
# [43, 47, 40, 17]
# [43, 47, 40, 29]
# [43, 47, 40, 41]
# [43, 47, 40, 53]
# [43, 47, 52, 29]
# [43, 47, 52, 41]
# [43, 47, 52, 53]
# [43, 47, 52, 65]
# [43, 47, 64, 41]
# [43, 47, 64, 53]
# [43, 47, 64, 65]
# [43, 47, 64, 77]
# [43, 59, 40, 17]
# [43, 59, 40, 29]
# [43, 59, 40, 41]
# [43, 59, 40, 53]
# [43, 59, 52, 29]
# [43, 59, 52, 41]
# [43, 59, 52, 53]
# [43, 59, 52, 65]
# [43, 59, 64, 41]
# [43, 59, 64, 53]
# [43, 59, 64, 65]
# [43, 59, 64, 77]
# [43, 59, 76, 53]
# [43, 59, 76, 65]
# [43, 59, 76, 77]
# [43, 59, 76, 89]
# [43, 23, 4, -15]
# [43, 23, 4, -3]
# [43, 23, 4, 9]
# [43, 23, 4, 21]
# [43, 23, 16, -3]
# [43, 23, 16, 9]
# [43, 23, 16, 21]
# [43, 23, 16, 33]
# [43, 23, 28, 9]
# [43, 23, 28, 21]
# [43, 23, 28, 33]
# [43, 23, 28, 45]
# [43, 23, 40, 21]
# [43, 23, 40, 33]
# [43, 23, 40, 45]
# [43, 23, 40, 57]
# [43, 35, 16, -3]
# [43, 35, 16, 9]
# [43, 35, 16, 21]
# [43, 35, 16, 33]
# [43, 35, 28, 9]
# [43, 35, 28, 21]
# [43, 35, 28, 33]
# [43, 35, 28, 45]
# [43, 35, 40, 21]
# [43, 35, 40, 33]
# [43, 35, 40, 45]
# [43, 35, 40, 57]
# [43, 35, 52, 33]
# [43, 35, 52, 45]
# [43, 35, 52, 57]
# [43, 35, 52, 69]
# [43, 47, 28, 9]
# [43, 47, 28, 21]
# [43, 47, 28, 33]
# [43, 47, 28, 45]
# [43, 47, 40, 21]
# [43, 47, 40, 33]
# [43, 47, 40, 45]
# [43, 47, 40, 57]
# [43, 47, 52, 33]
# [43, 47, 52, 45]
# [43, 47, 52, 57]
# [43, 47, 52, 69]
# [43, 47, 64, 45]
# [43, 47, 64, 57]
# [43, 47, 64, 69]
# [43, 47, 64, 81]
# [43, 59, 40, 21]
# [43, 59, 40, 33]
# [43, 59, 40, 45]
# [43, 59, 40, 57]
# [43, 59, 52, 33]
# [43, 59, 52, 45]
# [43, 59, 52, 57]
# [43, 59, 52, 69]
# [43, 59, 64, 45]
# [43, 59, 64, 57]
# [43, 59, 64, 69]
# [43, 59, 64, 81]
# [43, 59, 76, 57]
# [43, 59, 76, 69]
# [43, 59, 76, 81]
# [43, 59, 76, 93]
# [43, 23, 9, -12]
# [43, 23, 9, 0]
# [43, 23, 9, 12]
# [43, 23, 9, 24]
# [43, 23, 21, 0]
# [43, 23, 21, 12]
# [43, 23, 21, 24]
# [43, 23, 21, 36]
# [43, 23, 33, 12]
# [43, 23, 33, 24]
# [43, 23, 33, 36]
# [43, 23, 33, 48]
# [43, 23, 45, 24]
# [43, 23, 45, 36]
# [43, 23, 45, 48]
# [43, 23, 45, 60]
# [43, 35, 21, 0]
# [43, 35, 21, 12]
# [43, 35, 21, 24]
# [43, 35, 21, 36]
# [43, 35, 33, 12]
# [43, 35, 33, 24]
# [43, 35, 33, 36]
# [43, 35, 33, 48]
# [43, 35, 45, 24]
# [43, 35, 45, 36]
# [43, 35, 45, 48]
# [43, 35, 45, 60]
# [43, 35, 57, 36]
# [43, 35, 57, 48]
# [43, 35, 57, 60]
# [43, 35, 57, 72]
# [43, 47, 33, 12]
# [43, 47, 33, 24]
# [43, 47, 33, 36]
# [43, 47, 33, 48]
# [43, 47, 45, 24]
# [43, 47, 45, 36]
# [43, 47, 45, 48]
# [43, 47, 45, 60]
# [43, 47, 57, 36]
# [43, 47, 57, 48]
# [43, 47, 57, 60]
# [43, 47, 57, 72]
# [43, 47, 69, 48]
# [43, 47, 69, 60]
# [43, 47, 69, 72]
# [43, 47, 69, 84]
# [43, 59, 45, 24]
# [43, 59, 45, 36]
# [43, 59, 45, 48]
# [43, 59, 45, 60]
# [43, 59, 57, 36]
# [43, 59, 57, 48]
# [43, 59, 57, 60]
# [43, 59, 57, 72]
# [43, 59, 69, 48]
# [43, 59, 69, 60]
# [43, 59, 69, 72]
# [43, 59, 69, 84]
# [43, 59, 81, 60]
# [43, 59, 81, 72]
# [43, 59, 81, 84]
# [43, 59, 81, 96]
# [43, 23, 9, -7]
# [43, 23, 9, 5]
# [43, 23, 9, 17]
# [43, 23, 9, 29]
# [43, 23, 21, 5]
# [43, 23, 21, 17]
# [43, 23, 21, 29]
# [43, 23, 21, 41]
# [43, 23, 33, 17]
# [43, 23, 33, 29]
# [43, 23, 33, 41]
# [43, 23, 33, 53]
# [43, 23, 45, 29]
# [43, 23, 45, 41]
# [43, 23, 45, 53]
# [43, 23, 45, 65]
# [43, 35, 21, 5]
# [43, 35, 21, 17]
# [43, 35, 21, 29]
# [43, 35, 21, 41]
# [43, 35, 33, 17]
# [43, 35, 33, 29]
# [43, 35, 33, 41]
# [43, 35, 33, 53]
# [43, 35, 45, 29]
# [43, 35, 45, 41]
# [43, 35, 45, 53]
# [43, 35, 45, 65]
# [43, 35, 57, 41]
# [43, 35, 57, 53]
# [43, 35, 57, 65]
# [43, 35, 57, 77]
# [43, 47, 33, 17]
# [43, 47, 33, 29]
# [43, 47, 33, 41]
# [43, 47, 33, 53]
# [43, 47, 45, 29]
# [43, 47, 45, 41]
# [43, 47, 45, 53]
# [43, 47, 45, 65]
# [43, 47, 57, 41]
# [43, 47, 57, 53]
# [43, 47, 57, 65]
# [43, 47, 57, 77]
# [43, 47, 69, 53]
# [43, 47, 69, 65]
# [43, 47, 69, 77]
# [43, 47, 69, 89]
# [43, 59, 45, 29]
# [43, 59, 45, 41]
# [43, 59, 45, 53]
# [43, 59, 45, 65]
# [43, 59, 57, 41]
# [43, 59, 57, 53]
# [43, 59, 57, 65]
# [43, 59, 57, 77]
# [43, 59, 69, 53]
# [43, 59, 69, 65]
# [43, 59, 69, 77]
# [43, 59, 69, 89]
# [43, 59, 81, 65]
# [43, 59, 81, 77]
# [43, 59, 81, 89]
# [43, 59, 81, 101]
# [43, 23, 9, -3]
# [43, 23, 9, 9]
# [43, 23, 9, 21]
# [43, 23, 21, 9]
# [43, 23, 21, 21]
# [43, 23, 21, 33]
# [43, 23, 33, 21]
# [43, 23, 33, 33]
# [43, 23, 33, 45]
# [43, 23, 45, 33]
# [43, 23, 45, 45]
# [43, 23, 45, 57]
# [43, 35, 21, 9]
# [43, 35, 21, 21]
# [43, 35, 21, 33]
# [43, 35, 33, 21]
# [43, 35, 33, 33]
# [43, 35, 33, 45]
# [43, 35, 45, 33]
# [43, 35, 45, 45]
# [43, 35, 45, 57]
# [43, 35, 57, 45]
# [43, 35, 57, 57]
# [43, 35, 57, 69]
# [43, 47, 33, 21]
# [43, 47, 33, 33]
# [43, 47, 33, 45]
# [43, 47, 45, 33]
# [43, 47, 45, 45]
# [43, 47, 45, 57]
# [43, 47, 57, 45]
# [43, 47, 57, 57]
# [43, 47, 57, 69]
# [43, 47, 69, 57]
# [43, 47, 69, 69]
# [43, 47, 69, 81]
# [43, 59, 45, 33]
# [43, 59, 45, 45]
# [43, 59, 45, 57]
# [43, 59, 57, 45]
# [43, 59, 57, 57]
# [43, 59, 57, 69]
# [43, 59, 69, 57]
# [43, 59, 69, 69]
# [43, 59, 69, 81]
# [43, 59, 81, 69]
# [43, 59, 81, 81]
# [43, 59, 81, 93]

# %% [markdown]
# ### Previewing these results
#
# I'm quite satisfied with this approach. It's a lot more intuitive and intervallic than the first algorithm.
#
# So, now, the only thing left to do is to build a preview clip of all of this.
#
# I'm going to enumerate melodies over the axis chords. C, G, Am, F.
#
# 1. I'll define a list of pitch class sets representing these chords.
# 2. I'll derive a list of pitch sets from these pcsets.
# 3. I'll derive a list of pitch sequences from these pcsets.
# 4. I'll build a clip that zips together these pseqs and psets and plays them all out end to end.
#
# Hell yeah.

# %%
from itertools import cycle

from harmonica.utility import GM


pcset_seq = [
    PitchClassSet(p_classes, 12)
    for p_classes in [[0, 4, 7], [2, 7, 11], [0, 4, 9], [0, 5, 9]]
]

psets = cycle(
    [
        PitchSet(pitches) + 48
        for pitches in [[0, 4, 7], [-1, 2, 7], [0, 4, 9], [0, 5, 9]]
    ]
)

pseqs = pcsets_to_pseqs_relative(pcset_seq, 6, 0)

melody = NoteClip().set_program(GM.Piccolo)
chords = NoteClip().set_program(GM.ElectricPiano1)

onset = Mixed(0)
delta = Mixed(2)

for pitch_sequence in pseqs:
    for i, pitch in enumerate(pitch_sequence):
        pset = next(psets)
        melody.add_event(Note(pitch, onset, delta))
        chords.add_event(pset.to_clip(onset, delta))
        onset += delta

# Uncomment this to preview
# Clip([melody, chords]).preview(tempo=90)

# %% [markdown]
# Delightful!
